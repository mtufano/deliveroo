# %%
import inspect
import json
import logging
import os.path as path
from json import loads
from os import makedirs
from pathlib import Path

import validators
from bs4 import BeautifulSoup
from pandas import DataFrame, read_csv, concat
from requests import get, HTTPError

logging.basicConfig(format="%(asctime)s - [%(levelname)s]\t%(message)s",
                    datefmt='%d-%b-%y %H:%M:%S')

# %%
url = "https://deliveroo.co.uk/menu/London/king's-cross/10709-kfc-kings-cross-uk?day=today&postcode=EC&time=ASAP"
#"https://deliveroo.co.uk/menu/London/hop-west-end/morrisons-new-oxford-street?day=today&postcode=EC&time=ASAP",
#"https://deliveroo.co.uk/menu/London/camden-road/three-uncles-camden?day=today&postcode=EC&time=ASAP",
#"https://deliveroo.co.uk/menu/London/highbury/patty-guy-at-the-horatia?day=today&postcode=EC&time=ASAP"]

# %%
def url_validator(link: str) -> bool:
    """
    The function validates whether a given string is a valid URL of talabat.com or not
    :rtype: bool
    :param link: A string to be validated as URL or not
    :return: True if URL, else False
    """
    if validators.url(link) and (link.startswith('https://deliveroo.co.uk/')):
        return True
    else:
        return False

def __init__(self, url: str, base_dir: str = 'crawled_data',
             f_name: str = 'crawled_data', menu_dir: str = 'menus') -> None:
    """
    :rtype: None
    :param url: URL for data crawl
    :param base_dir: Directory to save data
    :param menu_dir: Directory to save menus
    """
    self.__flag = True
    self.__details_json = None
    self.__bs4_data = None

    self.__restaurant_details = {}
    self.__restaurant_menu_details = []

    frame = inspect.stack()[1]
    filename = frame[0].f_code.co_filename
    filepath = Path(path.dirname(filename))

    self.__filename = f_name

    if path.isabs(base_dir):
        self.__base_dir = Path(base_dir)
    else:
        self.__base_dir = filepath / base_dir

    if path.isabs(menu_dir):
        self.__menu_dir = Path(menu_dir)
    else:
        self.__menu_dir = self.__base_dir / menu_dir

    try:
        if self.url_validator(url):
            self.url = url
        else:
            self.url = url
            raise TypeError(f"'{url}' is not a valid URL")

    except TypeError as e:
        self.url = None
        self.__flag = False
        logging.error(e)

    except Exception as e:
        self.url = None
        self.__flag = False
        logging.debug(e)

    # calling other function(s)
    if self.__flag:
        self.__fetch_details()

# %%
def fetch_details(url):
    try:
        raw = get(url, allow_redirects=True, headers=(
            {
                'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
                              '(KHTML, like Gecko) Chrome/102.0.5005.63 Safari/537.36',
            }
        ))

        status_code = raw.status_code
        reason = raw.reason

        if status_code != 200:
            raise HTTPError(status_code, reason)

        bs4_data = BeautifulSoup(raw.content, 'lxml')
        print(bs4_data)
        return bs4_data
    
    except HTTPError as e:
        flag = False
        err = f"{self.url} - {e.strerror} [{e.errno}]"
        bs4_data = None
        logging.error(err)


    except Exception as e:
        flag = False
        bs4_data = None
        logging.debug(e)

# %%
url_validator(url)
# Out:
# True

# %%
bs4_data = fetch_details(url)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en"><head><title>KFC - Kings Cross delivery from King's Cross - Order with Deliveroo</title><meta content="The best local restaurants and takeaways are here to deliver. Order on Deliveroo today!" name="description"/><meta name="nosnippet"/><link href="https://deliveroo.co.uk/menu/London/king's-cross/10709-kfc-kings-cross-uk" rel="canonical"/><meta content="https://deliveroo.co.uk/menu/London/king's-cross/10709-kfc-kings-cross-uk" property="og:url"/><meta content="KFC - Kings Cross on Deliveroo" property="og:title"/><meta content="Serving up amazing food, KFC - Kings Cross sits in the heart of King's Cross. With dishes you're guaranteed to love, order now for delivery within 32 minutes" property="og:description"/><meta content="https://rs-menus-api.roocdn.com/images/29f7b700-9280-466d-b5f5-d3ef036b49f5/image.jpeg?width=1200&amp;height=630&amp;fit=crop" property="og:image"/><meta content="1200" property="og:image:width"/><meta content="630" property="og:image:height"/><meta content="KFC - Kings Cross on Deliveroo" property="twitter:title"/><meta content="@Deliveroo" property="twitter:site"/><meta content="summary_large_image" property="twitter:card"/><meta content="Serving up amazing food, KFC - Kings Cross sits in the heart of King's Cross. With dishes you're guaranteed to love, order now for delivery within 32 minutes" property="twitter:description"/><meta content="https://rs-menus-api.roocdn.com/images/29f7b700-9280-466d-b5f5-d3ef036b49f5/image.jpeg?width=1200&amp;height=630&amp;fit=crop" property="twitter:image"/><script type="text/javascript">window.dataLayer = window.dataLayer || [];function gtag(){dataLayer.push(arguments);}
#                gtag('consent', 'default', {ad_storage: 'denied', analytics_storage: 'denied', wait_for_update: 500, });</script><script type="text/javascript">window.dataLayer = window.dataLayer || [];function gtag(){dataLayer.push(arguments);}
#                var cookiesGroup = window.dataLayer.find((x) => x.event === 'OptanonLoaded')
#                var categories = cookiesGroup ? cookiesGroup.OptanonActiveGroups.split(',') : [];
#                var analyticsStorage = categories.includes('C0002') ? 'granted' : 'denied';
#                var adStorage = categories.includes('C0004') ? 'granted' : 'denied';
#                gtag('consent', 'update', {ad_storage: adStorage, analytics_storage: analyticsStorage,});</script><script type="text/javascript">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                 'https://www.googletagmanager.com/gtm.js?id='+i+dl+'';f.parentNode.insertBefore(j,f);
#                 })(window,document,'script','dataLayer','GTM-PMJMHHC');</script><link color="#009e99" href="data:image/svg+xml;base64,..." rel="mask-icon"/><link href="https://cwa.roocdn.com/foh/littlefarm/apple-touch-icon.png?v=1627305556544" rel="apple-touch-icon-precomposed" sizes="57x57"/><link href="https://cwa.roocdn.com/foh/littlefarm/apple-touch-icon.png?v=1627305556544" rel="apple-touch-icon-precomposed" sizes="72x72"/><link href="https://cwa.roocdn.com/foh/littlefarm/apple-touch-icon.png?v=1627305556544" rel="apple-touch-icon-precomposed" sizes="120x120"/><link href="https://cwa.roocdn.com/foh/littlefarm/apple-touch-icon.png?v=1627305556544" rel="apple-touch-icon-precomposed" sizes="144x144"/><link href="https://cwa.roocdn.com/foh/littlefarm/apple-touch-icon.png?v=1627305556544" rel="apple-touch-icon-precomposed" sizes="152x152"/><link href="https://cwa.roocdn.com/foh/littlefarm/favicon.png?v=1627305556544" rel="shortcut icon" sizes="32x32" type="image/png"/><link href="//consumer-component-library.roocdn.com/26.19.3/consumer-component-library.css" rel="stylesheet" type="text/css"/><link as="font" crossorigin="anonymous" href="//consumer-component-library.roocdn.com/26.19.3/static/fonts/IBMPlexSans-Regular.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="//consumer-component-library.roocdn.com/26.19.3/static/fonts/stratos-semibold.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="//consumer-component-library.roocdn.com/26.19.3/static/fonts/IBMPlexSans-Bold.woff2" rel="preload" type="font/woff2"/><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><meta content="#009e99" name="theme-color"/><script>history.scrollRestoration = "manual"</script><meta content="35" name="next-head-count"/><script src="https://cdn.polyfill.io/v3/polyfill.min.js?features=default%2Ces6%7Cgated%2CArray.prototype.includes%7Cgated%2CArray.prototype.find%7Cgated%2CArray.prototype.flat%7Cgated%2CArray.prototype.flatMap%7Cgated%2CIntersectionObserver%2CObject.values%7Cgated%2CObject.fromEntries%7Cgated%2CString.prototype.replaceAll%7Cgated"></script><script charset="UTF-8" data-document-language="true" data-domain-script="352f2419-98d3-478f-b45d-3d7b1f8e1880" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript"></script><script>!function(){if('PerformanceLongTaskTiming' in window){var g=window.__tti={e:[]};g.o=new PerformanceObserver(function(l){g.e=g.e.concat(l.getEntries())});g.o.observe({entryTypes:['longtask']})}}();</script><script>!function(n,e){var t,o,i,c=[],f={passive:!0,capture:!0},r=new Date,a="pointerup",u="pointercancel";function p(n,c){t||(t=c,o=n,i=new Date,w(e),s())}function s(){o>=0&&o<i-r&&(c.forEach(function(n){n(o,t)}),c=[])}function l(t){if(t.cancelable){var o=(t.timeStamp>1e12?new Date:performance.now())-t.timeStamp;"pointerdown"==t.type?function(t,o){function i(){p(t,o),r()}function c(){r()}function r(){e(a,i,f),e(u,c,f)}n(a,i,f),n(u,c,f)}(o,t):p(o,t)}}function w(n){["click","mousedown","keydown","touchstart","pointerdown"].forEach(function(e){n(e,l,f)})}w(n),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstInputDelay=function(n){c.push(n),s()}}(addEventListener,removeEventListener);</script><link href="/manifest" rel="manifest"/><link as="style" href="https://cwa.roocdn.com/_next/static/css/378e4432ed15c410.css" rel="preload"/><link data-n-g="" href="https://cwa.roocdn.com/_next/static/css/378e4432ed15c410.css" rel="stylesheet"/><link as="style" href="https://cwa.roocdn.com/_next/static/css/99f29da5a0ee8656.css" rel="preload"/><link data-n-p="" href="https://cwa.roocdn.com/_next/static/css/99f29da5a0ee8656.css" rel="stylesheet"/><link as="style" href="https://cwa.roocdn.com/_next/static/css/cf9db88619ada1df.css" rel="preload"/><link href="https://cwa.roocdn.com/_next/static/css/cf9db88619ada1df.css" rel="sty ...
#
# Serves 4 people. The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">1440 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£17.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Bargain Bucket: 10 pc" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Bargain Bucket: 10 pc</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">10 pieces of our famous Original Recipe chicken with 4 regular fries. Serious bang for your buck.
#
# Serves 4 people. The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">2400 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£22.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Bargain Bucket: 14 pc" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Bargain Bucket: 14 pc</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">14 pieces of our famous Original Recipe chicken with 4 regular fries. Serious bang for your buck.
#
# Serves 4 people. The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">3360 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£26.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Family Feast: 6 pc" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Family Feast: 6 pc</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">6 pieces of our famous Original Recipe chicken, 4 regular fries, 2 large sides &amp; a large bottle of drink. One for all the flock.
#
# Serves 4 people. The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">1440 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£19.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Family Feast: 10 pc" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Family Feast: 10 pc</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">10 pieces of our famous Original Recipe chicken, 4 regular fries, 2 large sides &amp; a large bottle of drink. One for all the flock.
#
# Serves 4 people. The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">2400 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£24.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Wicked Variety Bucket: 6 pc" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Wicked Variety Bucket: 6 pc</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">6 pieces of Original Recipe chicken, 8 Hot Wings, 4 Mini Fillets &amp; 4 regular fries. A fiery one for all the flock.
#
# Serves 4 people. The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">1960 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£22.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Wicked Variety Bucket: 10 pc" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Wicked Variety Bucket: 10 pc</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">10 pieces of Original Recipe chicken, 8 Hot Wings, 4 Mini Fillets &amp; 4 regular fries. A fiery one for all the flock.
#
# Serves 4 people. The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">2400 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£27.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Dipping Boneless Feast: 8 pc" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Dipping Boneless Feast: 8 pc</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">8 Mini Fillets, large Popcorn chicken, 4 regular fries &amp; 2 large sides. Plus 4 Original Dips &amp; a large bottle of drink. Dippin' delicious.
#
# Serves 4 people. The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">1040 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£22.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Dipping Boneless Feast: 12 pc" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Dipping Boneless Feast: 12 pc</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">12 Mini Fillets, large Popcorn chicken, 4 regular fries &amp; 2 large sides. Plus 4 Original Dips &amp; a large bottle of drink. Dippin' delicious.
#
# Serves 4 people. The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">1560 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£27.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Party Bucket" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Party Bucket</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">14 pieces of Original Recipe chicken, 8 Hot Wings, 8 Mini Fillets, large Popcorn chicken, 6 regular fries &amp; 2 large sides. Plus a 1.5L bottle of drink. The ultimate finger lickin’ feast.
#
# Serves 6 people. The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">3360 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£39.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Boneless Bundle: 8 PC" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Boneless Bundle: 8 PC</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">The perfect boneless duo. 8 Mini Fillets and Regular Popcorn Chicken for just £10!</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">1050 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£10.00</span><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-89c73b0906008f40">Popular</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li></ul></div><div class="Layout-4549ebf43c78c99a" id="layout-133122695"><div class="Layout-2515809e54db56a7" data-testid="layout-head"><div class=""><div class="ccl-fe8408b3d372c9cd"><div class="ccl-955fe0ab28803310"><div class="Layout-acd23e46648eee23"><h2 class="ccl-cc80f737565f5a11 ccl-de2d30f2fc9eac3e ccl-b2e0b0752cacdc85 ccl-6bb677476f666349">Box Meals</h2></div><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">The perfect choice to fill you up.</p></div></div></div></div><ul class="UILayoutList-35695df5e1d82d37"><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Boneless Banquet" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Boneless Banquet</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">3 Mini Fillets, small Popcorn chicken, regular fries &amp; your choice of side. Plus one Original Dip &amp; a drink. Dippin' delicious.
#
# The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">390 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£10.49</span><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-89c73b0906008f40">Popular</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Trilogy Box Meal" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Trilogy Box Meal</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">Fiery Zinger Burger, Mini Fillet, small Popcorn chicken, regular fries &amp; your choice of side. Plus 1 Original Dip &amp; a drink. The triple whammy.
#
# The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">420 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£11.49</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Fillet Box Meal with 1 pc Chicken" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Fillet Box Meal with 1 pc Chicken</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><div class="UILines-eb427a2507db75b3 UILines-32dccbea0804e3af"><span class="DynamicIcon-8138ee56b0356f25"><span class="ccl-7c70b5273af79fe5 ccl-ab78be2f3c0b8a03"></span></span><span class="ccl-5026d3170fbe569d"></span><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-35aeda89048441ce">Highly rated</span></div> · <span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">Our Fillet Burger &amp; a piece of Original Recipe chicken. Plus regular fries, your choice of side &amp; a drink. An Original favourite.
#
# The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">455 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£9.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Zinger Box Meal with 2 Hot Wings 🔥" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Zinger Box Meal with 2 Hot Wings 🔥</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">Zinger Burger plus 2 fiery Hot Wings, regular fries, your choice of side &amp; a drink. Put a zing in your step!
#
# The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">420 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£9.99</span><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-89c73b0906008f40">Popular</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Fillet Box Meal with 2 Hot Wings" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Fillet Box Meal with 2 Hot Wings</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">Fillet Burger with 2 fiery Hot Wings, regular fries, your choice of side &amp; a drink. Original Recipe with a side of spice.
#
# The calorie information for this meal does not include the selectable items below.
# </span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">455 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£9.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Zinger Box Meal with 1 pc Chicken 🔥" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Zinger Box Meal with 1 pc Chicken 🔥</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">Zinger Burger plus 1 piece of Original Recipe chicken, regular fries, your choice of side &amp; a drink. The best KFC flavours in a box.
#
# The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">450 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£9.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Fillet Tower Box Meal with 1 pc Chicken" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Fillet Tower Box Meal with 1 pc Chicken</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">Fillet Burger topped with a hash brown &amp; cheese with a piece of Original Recipe chicken. Plus regular fries, your choice of side &amp; a drink. The true Original.
#
# The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">620 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£10.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Fillet Tower Box Meal with 2 Hot Wings" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Fillet Tower Box Meal with 2 Hot Wings</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">Fillet Burger topped with hash brown &amp; cheese with 2 fiery Hot Wings, regular fries, your choice of side &amp; a drink. Original Recipe with a side of spice.
#
# The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">605 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£10.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Zinger Tower Box Meal with 1 pc Chicken 🔥" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Zinger Tower Box Meal with 1 pc Chicken 🔥</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">Zinger Tower Burger topped with a hash brown, cheese &amp; tangy salsa. Plus 1 piece of Original Recipe chicken, regular fries, your choice of side &amp; a drink. Spice with a side of Original Recipe.
#
# The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">565 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£10.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Zinger Tower Box Meal with 2 Hot Wings 🔥" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Zinger Tower Box Meal with 2 Hot Wings 🔥</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">Zinger Tower Burger topped with a hash brown, cheese &amp; tangy salsa. Plus 2 Hot Wings, regular fries, your choice of side &amp; a drink. It’s a zing thing.
#
# The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">595 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£10.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Twister Wrap Box Meal with 1 Mini Fillet" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Twister Wrap Box Meal with 1 Mini Fillet</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">An Original Recipe fillet with crunchy pickled slaw and your choice of sauce, wrapped in a lightly toasted tortilla plus a boneless Mini Fillet strip, regular fries, your choice of side &amp; a drink. Make lunch a big deal.
#
# The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">450 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£9.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li></ul></div><div class="Layout-4549ebf43c78c99a" id="layout-133122687"><div class="Layout-2515809e54db56a7" data-testid="layout-head"><div class=""><div class="ccl-fe8408b3d372c9cd"><div class="ccl-955fe0ab28803310"><div class="Layout-acd23e46648eee23"><h2 class="ccl-cc80f737565f5a11 ccl-de2d30f2fc9eac3e ccl-b2e0b0752cacdc85 ccl-6bb677476f666349">Burgers</h2></div><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">Go classic with our Original Recipe burger or spice things up with Zinger. </p></div></div></div></div><ul class="UILayoutList-35695df5e1d82d37"><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Fillet Burger Meal" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Fillet Burger Meal</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">Original Recipe Fillet Burger made with chicken breast. With regular fries &amp; a drink. You can’t go wrong.
#
# The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">475 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£7.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Zinger Burger Meal 🔥" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Zinger Burger Meal 🔥</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">Zinger Burger made with chicken breast. Plus regular fries &amp; a drink. The meal with a kick.
#
# The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">450 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£7.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Fillet Tower Burger Meal" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Fillet Tower Burger Meal</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">Our Original Recipe Fillet Burger topped with a crispy hash brown &amp; cheese, plus regular fries &amp; a drink. You can’t go wrong.
#
# The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">605 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£8.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Zinger Tower Burger Meal 🔥" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Zinger Tower Burger Meal 🔥</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">Zinger Tower Burger topped with hash brown, cheese &amp; tangy salsa. Plus regular fries &amp; a drink. The meal with a kick.
#
# The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">565 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£8.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Zinger Stacker Meal 🔥" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Zinger Stacker Meal 🔥</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">2 Zinger Fillets topped with 2 slices of cheese, Supercharger &amp; sweet chilli sauce. Plus regular fries &amp; a drink. The meal with double the kick.
#
# The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">755 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£9.99</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Fillet Burger " class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Fillet Burger </p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">Original Recipe Fillet Burger. You can't go wrong.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">475 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£6.49</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Zinger Burger 🔥" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Zinger Burger 🔥</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">Spicy Zinger Fillet Burger. Packs a zingy punch.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">450 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£6.49</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Fillet Tower Burger " class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Fillet Tower Burger </p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">Original Recipe Fillet Burger topped with crispy hashbrown &amp; cheese. The Godfather of all burgers.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">620 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£7.49</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd ...
#
# ...
#
# Serves 6 people</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">285 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£3.49</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Pepsi MAX Can" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Pepsi MAX Can</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">MAXIMUM TASTE, NO SUGAR. A bold and refreshing fizzy drink. Delivered chilled.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">1 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£1.79</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Tango Can" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Tango Can</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">Unleash refreshment with Tango’s big, bold Orange flavour, no sugar, and low calorie carbonated soft drink. Delivered chilled.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">63 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£1.79</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Still Water 500ml" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Still Water 500ml</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">Crisp refreshing taste. Delivered chilled.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">0 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£1.79</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentati ...
#
# The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">265 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£5.49</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Kids' Bucket: Mini Fillet &amp; Dip" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Kids' Bucket: Mini Fillet &amp; Dip</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">A Mini Fillet with a Real Tomato dip, regular side, regular drink, plus a real fruit pineapple stick. Small in size, big on flavour.
#
# The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">130 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£5.49</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li><li><div class="MenuItemCard-a927b3314fc88b17"><div aria-label="Kids' Bucket: Popcorn Chicken" class="MenuItemCard-7036f1acc28e0949" role="button" tabindex="0"></div><div class="MenuItemCard-1e17f722e482e103"><div class="MenuItemCard-03b1bfbfe7cb723c"><p class="ccl-649204f2a8e630fd ccl-a396bc55704a9c8a ccl-0956b2f88e605eb8 ccl-ff5caa8a6f2b96d0 ccl-40ad99f7b47f3781">Kids' Bucket: Popcorn Chicken</p><div class="MenuItemCard-d6db654c8b51be41 MenuItemCard-394d34c2824eaf4f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-08c109442f3e666d">Our Popcorn chicken pieces with regular side, regular drink, plus a real fruit pineapple stick. Small in size, big on flavour.
#
# The calorie information for this meal does not include the selectable items below.</span></div><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d ccl-40ad99f7b47f3781 ccl-5cae55d5d78c131f">135 kcal</p><div class="MenuItemCard-bd0c8b7203436423 ccl-5cae55d5d78c131f"><span class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-32ec9a3197735a65 ccl-08c109442f3e666d">£5.49</span></div></div><div class="MenuItemCard-ff35664fd9aa5264" data-testid="menu-item-image"><div class="ccl-a897ba3fd642670d ccl-92294f995a389ac9" role="presentation"><div class="ccl-3d48bd3b2c7202f8"></div></div></div></div></div></li></ul></div></div><div class="MenuLayouts-1fe37f9f68a8dad9"><div class="Basket-3539a77e4e7ac46e"><div class="Basket-c6fc40ac4605dde6"><div class="Basket-c997e076cd534078 ccl-a5e1512b87ef2079"><div class="Basket-b2356c56643bf0c6"><span class="ccl-5a4995d6b654c92f ccl-7be8185d0a980278"><button class="ccl-388f3fb1d79d6a36 ccl-6d2d597727bd7bab ccl-59eced23a4d9e077 ccl-7be8185d0a980278 ccl-18419a95661cda93" disabled="" tabindex="-1" type="button"><span class="ccl-bc70252bc472695a">Go to checkout</span></button></span></div><div class="Basket-00ece298090d6218"><span class="ccl-5a4995d6b654c92f ccl-7be8185d0a980278"><button class="ccl-388f3fb1d79d6a36 ccl-6d2d597727bd7bab ccl-59eced23a4d9e077 ccl-7be8185d0a980278" tabindex="0" type="button"><span class="ccl-bc70252bc472695a"><div class="Basket-b2f782cc96c5521d"><span class="Basket-fcebe336eba70a1d">0</span><span>View basket</span><div class="Basket-cc61671a5a1a1d80"><span class="ccl-649204f2a8e630fd ccl-98a86d2cf2dd0739 ccl-33e28cffb44ce93d">£NaN.undefined</span></div></div></span></button></span></div></div></div></div></div></div></div></div></div><div class="" id="page-footer"><footer class="ccl-cbc48dd5ee5b3654"><div class="ccl-a4804aefec8d4dba"><nav class="ccl-4142f9efb8e33fca"><div class="ccl-f6f56d7716fe7b68"><div class="ccl-644895e35e4e0c38"><div class="ccl-de3c47a1a8a0e354"><h3 class="ccl-cc80f737565f5a11 ccl-ccd255d0081a98ee ccl-b2e0b0752cacdc85 ccl-05fe5040ccbb86ff ccl-ec09a820e95fce93 ccl-8f2c2613eb9de320 ccl-9905ab9a1d113e6b ccl-91b0e11c0b8cf572">Discover Deliveroo</h3><ul class="ccl-8db564d64ac86f2b"><li class="ccl-fde7412b382aa4b7"><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-83e0d1140ac29f91 ccl-40ad99f7b47f3781"><a class="ccl-dd9c911e351f6b20" href="https://corporate.deliveroo.co.uk">Investors</a></p></li><li class="ccl-fde7412b382aa4b7"><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-83e0d1140ac29f91 ccl-40ad99f7b47f3781"><a class="ccl-dd9c911e351f6b20" href="/about-us">About us</a></p></li><li class="ccl-fde7412b382aa4b7"><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-83e0d1140ac29f91 ccl-40ad99f7b47f3781"><a class="ccl-dd9c911e351f6b20" href="/takeaway/">Takeaway</a></p></li><li class="ccl-fde7412b382aa4b7"><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-83e0d1140ac29f91 ccl-40ad99f7b47f3781"><a class="ccl-dd9c911e351f6b20" href="/more/">More</a></p></li><li class="ccl-fde7412b382aa4b7"><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-83e0d1140ac29f91 ccl-40ad99f7b47f3781"><a class="ccl-dd9c911e351f6b20" href="https://uk.deliveroo.news/">Newsroom</a></p></li><li class="ccl-fde7412b382aa4b7"><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-83e0d1140ac29f91 ccl-40ad99f7b47f3781"><a class="ccl-dd9c911e351f6b20" href="https://deliveroo.engineering">Engineering blog</a></p></li><li class="ccl-fde7412b382aa4b7"><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-83e0d1140ac29f91 ccl-40ad99f7b47f3781"><a class="ccl-dd9c911e351f6b20" href="https://deliveroo.design">Design blog</a></p></li><li class="ccl-fde7412b382aa4b7"><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-83e0d1140ac29f91 ccl-40ad99f7b47f3781"><a class="ccl-dd9c911e351f6b20" href="/gift-cards">Gift Cards</a></p></li><li class="ccl-fde7412b382aa4b7"><p class="ccl-649204f2a8e630fd ccl-6f43f9bb8ff2d712 ccl-83e0d1140ac ...
#             if(navigator.serviceWorker) {
#               navigator.serviceWorker.getRegistrations().then(function(registrations) {
#                 registrations.forEach(function(reg) { reg.unregister() });
#               });
#               if(window.caches) {
#                 caches.keys().then(function(cacheNames) {
#                   cacheNames.forEach(function(name) { return caches.delete(name) })
#                 });
#               }
#             }
#           </script></div><script id="__NEXT_DATA__" type="application/json">{"props":{"initialState":{"account":{"loading":false,"errorMessage":"","addresses":[],"selectedAddress":{"isLoading":false},"rewards":{},"benefits":{},"subscription":{"cancellationDialog":{},"paymentModal":{"loading":false,"visible":false},"isPauseAndResumeSubscriptionModalOpen":false,"invoices":{"loading":false,"error":false,"subscriptionEvents":[]}},"vouchers":{"elements":[],"emptyState":{},"redeemed":{"loading":false,"error":null,"success":null}},"deletion":{"isSubmitting":false,"isVerifying":false},"tierSwitching":{"viewPlans":{},"availablePlans":[],"cancelPlan":{},"confirmPlan":{},"currentPlan":{},"isLoading":false,"success":false,"successBannerText":""},"banner":{"type":"error"},"password":{},"challenges":{"displayedChallengeDetailsModal":{"isLoading":false},"challengeAcceptedToast":{"isOpen":false},"acceptChallengeIsLoading":false,"challengesSections":[],"completedChallenges":{}},"marketingPreferences":{"marketingEmail":false,"transactionalPush":false,"marketingPush":false}},"address":{"errors":{"network":null,"graphql":[]},"isAddressModalOpen":false,"coordinates":null,"selectedPlaceId":null,"addressProgress":{"steps":3,"currentStep":1,"activeColor":{"hex":"#00ccbc"},"inactiveColor":{"hex":"#E8EBEB"}},"locationValidation":{"isLoading":false,"hasLocationBeenChecked":false,"isLocationServiced":true},"lastNavigationAction":"","currentActiveOrders":[],"isOrdersFetched":false,"modalType":"","dialogModal":{"isOpen":false,"modalType":""}},"apiRequests":{"GET_ACCOUNT_PAGE_PROPS":{"action":null,"data":null,"errorMessage":null,"requestState":"PENDING","statusCode":null}},"auth":{"logout":{},"login":{"errorMessage":"","showEmailLogin":false,"onlyShowSocialLogin":false,"marketingPreferences":[]},"passwordReset":{},"error":null,"csrfToken":"","csrfError":"","redirectPath":"","loading":false,"refetchCSRFToken":false,"newPassword":{"errorMessage":"","isStrongPassword":false,"strongPasswordCriteria":{"minimumLength":12,"numberOfDigits":1,"numberOfSymbols":1,"numberOfUpperCase":1,"numberOfLowerCase":1}}},"basket":{"loading":false},"checkoutBasket":{"loading":false,"basket":{},"payment":{},"tipping_enabled":false,"restaurant":{},"fulfillment_times":[],"has_scheduled_ranges":false},"brand":{"csrfToken":"","csrfLoading":false,"csrfError":null,"refetchCSRFToken":false,"redirectPath":"","error":null,"landing":{}},"brands":{},"checkoutPayment":{"alerts":{"hidden":[],"queue":[]},"lastAction":null,"paymentPlanId":null,"errors":{"hasDismissed":true,"network":null},"interactiveChallenge":{"details":null,"hasDismissed":true},"paymentOptions":{"completing":[],"selectedCompleting":null,"paypalConfig":null,"fundBalances":[]},"addresses":{"available":[],"selected":null,"hintCoordinates":null},"selectedAddressView":"","lineItemGroups":[],"fulfillmentDetails":null,"executionState":null,"executePaymentPlanData":{},"isLoading":false,"translatedContent":{"addNewAddressCta":"Add a new address","addPaypalCta":"Add a PayPal account"},"footerNote":null,"headerBanners":[],"cutleryRequested":false,"cutleryToggleAvailable":false,"itemSubstitution":null,"marketingPreferences":null,"feesEducationJSON":null,"termsAndConditionsBlock":null,"uiBlocksState":{"checkboxes":[],"mealCard":null,"selectedPaymentMethod":null},"blocks":[],"checkoutId":null,"user":null,"trackingData":null},"orderPaymentQrCode":{"qrCode":{"url":null,"iconUrl":null,"errors":null}},"orderReceipt":{"error":null,"restaurant":{"name":"","tld":"","address1":"","cityName":"","postCode":{"code":""},"phone":"","tzName":""},"user":{"fullName":""},"order":{"id":0,"isCompletedOrder":false,"isCustomerCollectionFulfilled":false,"isScheduled":false,"isReceiptAvailable":false,"isCompletionTargetToday":false,"isDeliveredAtToday":false,"scheduledTimeText":"","targetTime":"","targetDeliveryTime":"","deliveredAt":"","orderNumber":0,"subtotal":0,"total":0,"currencyCode":"","deliveryFee":0,"cardFee":0,"tip":0,"refundInvoices":false,"invoices": ...

# %%
def make_json (bs4_data):
    flag = True
    try:
        try:
            data = bs4_data.select('#__NEXT_DATA__')[0].text
            details_json = loads(data)
            return details_json
            #print(details_json)

        except Exception as e:
            flag = False
            details_json = None
            logging.error(e)


    except Exception as e:
        flag = False
        details_json = None
        logging.error(e)

    # call other function(s)
    if flag:
        fetch_restaurant_details()

# %%
details_json = make_json(bs4_data)

# %%
details_json
# Out:
# {'props': {'initialState': {'account': {'loading': False,
#     'errorMessage': '',
#     'addresses': [],
#     'rewards': {},
#     'benefits': {},
#     'subscription': {'cancellationDialog': {},
#      'paymentModal': {'loading': False, 'visible': False},
#      'isPauseAndResumeSubscriptionModalOpen': False,
#      'invoices': {'loading': False, 'error': False, 'subscriptionEvents': []}},
#     'vouchers': {'elements': [],
#      'emptyState': {},
#      'redeemed': {'loading': False, 'error': None, 'success': None}},
#     'deletion': {'isSubmitting': False, 'isVerifying': False},
#     'tierSwitching': {'viewPlans': {},
#      'availablePlans': [],
#      'cancelPlan': {},
#      'confirmPlan': {},
#      'currentPlan': {},
#      'isLoading': False,
#      'success': False,
#      'successBannerText': ''},
#     'banner': {'type': 'error'},
#     'password': {},
#     'challenges': {'displayedChallengeDetailsModal': {'isLoading': False},
#      'challengeAcceptedToast': {'isOpen': False},
#      'acceptChallengeIsLoading': False,
#      'challengesSections': [],
#      'completedChallenges': {}},
#     'marketingPreferences': {'marketingEmail': False,
#      'transactionalPush': False,
#      'marketingPush': False}},
#    'address': {'errors': {'network': None, 'graphql': []},
#     'isAddressModalOpen': False,
#     'coordinates': None,
#     'selectedPlaceId': None,
#     'addressProgress': {'steps': 3,
#      'currentStep': 1,
#      'activeColor': {'hex': '#00ccbc'},
#      'inactiveColor': {'hex': '#E8EBEB'}},
#     'locationValidation': {'isLoading': False,
#      'hasLocationBeenChecked': False,
#      'isLocationServiced': True},
#     'lastNavigationAction': ''},
#    'apiRequests': {'GET_ACCOUNT_PAGE_PROPS': {'action': None,
#      'data': None,
#      'errorMessage': None,
#      'requestState': 'PENDING',
#      'statusCode': None}},
#    'auth': {'logout': {},
#     'login': {'errorMessage': '',
#      'showEmailLogin': False,
#      'onlyShowSocialLogin': False,
#      'marketingPreferences': []},
#     'passwordReset': {},
#     'error': None,
#     'csrfToken': '',
#     'csrfError': '',
#     'redirectPath': '',
#     'loading': False,
#     'refetchCSRFToken': False,
#     'newPassword': {'errorMessage': '',
#      'isStrongPassword': False,
#      'strongPasswordCriteria': {'minimumLength': 12,
#       'numberOfDigits': 1,
#       'numberOfSymbols': 1,
#       'numberOfUpperCase': 1,
#       'numberOfLowerCase': 1}}},
#    'basket': {'loading': False},
#    'checkoutBasket': {'loading': False,
#     'basket': {},
#     'payment': {},
#     'tipping_enabled': False,
#     'restaurant': {},
#     'fulfillment_times': [],
#     'has_scheduled_ranges': False},
#    'brand': {'csrfToken': '',
#     'csrfLoading': False,
#     'csrfError': None,
#     'refetchCSRFToken': False,
#     'redirectPath': '',
#     'error': None,
#     'landing': {}},
#    'brands': {},
#    'checkoutPayment': {'alerts': {'hidden': [], 'queue': []},
#     'lastAction': None,
#     'paymentPlanId': None,
#     'errors': {'hasDismissed': True, 'network': None},
#     'interactiveChallenge': {'details': None, 'hasDismissed': True},
#     'paymentOptions': {'completing': [],
#      'selectedCompleting': None,
#      'paypalConfig': None,
#      'fundBalances': []},
#     'addresses': {'available': [], 'selected': None, 'hintCoordinates': None},
#     'selectedAddressView': '',
#     'lineItemGroups': [],
#     'fulfillmentDetails': None,
#     'executionState': None,
#     'executePaymentPlanData': {},
#     'isLoading': False,
#     'translatedContent': {'addNewAddressCta': 'Add a new address',
#      'addPaypalCta': 'Add a PayPal account'},
#     'footerNote': None,
#     'headerBanners': [],
#     'cutleryRequested': False,
#     'cutleryToggleAvailable': False,
#     'itemSubstitution': None,
#     'marketingPreferences': None,
#     'feesEducationJSON': None,
#     'termsAndConditionsBlock': None,
#     'uiBlocksState': {'checkboxes': [],
#      'mealCard': None,
#      'selectedPaymentMethod': None},
#     'blocks': [],
#     'checkoutId': None},
#    'orderPaymentQrCode': {'qrCode': {'url': None,
#      'iconUrl': None,
#      'errors': None}},
#    'orderReceipt': {'error': None,
#     'restaurant': {'name': '',
#      'tld': '',
#      'address1': '',
#      'cityName': '',
#      'postCode': {'code': ''},
#      'phone': '',
#      'tzName': ''},
#     'user': {'fullName': ''},
#     'order': {'id': 0,
#      'isCompletedOrder': False,
#      'isCustomerCollectionFulfilled': False,
#      'isScheduled': False,
#      'isReceiptAvailable': False,
#      'isCompletionTargetToday': False,
#      'isDeliveredAtToday': False,
#      'scheduledTimeText': '',
#      'targetTime': '',
#      'targetDeliveryTime': '',
#      'deliveredAt': '',
#      'orderNumber': 0,
#      'subtotal': 0,
#      'total': 0,
#      'currencyCode': '',
#      'deliveryFee': 0,
#      'cardFee': 0,
#      'tip': 0,
#      'refundInvoices': False,
#      'invoices': None,
#      'formattedAmounts': {'deliveryFee': '',
#       'deliveryFeeNoSymbol': '',
#       'formattedSubtotalNoSymbol': '',
#       'riderTip': '',
#       'riderTipNoSymbol': '',
#       'subtotal': '',
#       'total': ''},
#      'formattedTimes': {'deliveredAtLong': '',
#       'deliveredAtTime': '',
#       'deliveredAtDay': '',
#       'submittedAt': '',
#       'targetTimeTime': '',
#       'targetTimeDay': '',
#       'completionTargetDay': ''},
#      'rootItemsWithModifiers': [],
#      'address': {'address1': '',
#       'address2': '',
#       'city': '',
#       'postCode': {'code': ''},
#       'phone': ''}},
#     'orderArabic': None,
#     'info': {'supportEmail': ''},
#     'redirectUrl': None},
#    'config': {'countries': [{'id': 'au',
#       'name': 'Australia',
#       'host': 'deliveroo.com.au',
#       'isHidden': False,
#       'personalNames': 'first_last',
#       'roovite': {'inviteeAmount': 12,
#        'referrerAmount': 12,
#        'currencySymbol': '$',
#        'currencyCode': 'AUD',
#        'inviteeSteps': 4,
#        'referrerSteps': 4,
#        'creditExpiry': 30,
#        'minimumOrderValue': 20,
#        'isActive': True},
#       'social': {'twitter': 'Deliveroo_AU',
#        'instagram': 'deliveroo_au',
#        'facebook': 'deliverooau',
#        'facebookShareId': 153825428355668},
#       'blog': True,
#       'newsroomLink': 'https://au.deliveroo.news',
#       'careersLink': 'https://careers.deliveroo.com.au'},
#      {'id': 'be',
#       'name': 'Belgium',
#       'host': 'deliveroo.be',
#       'isHidden': False,
#       'personalNames': 'first_last',
#       'roovite': {'inviteeAmount': 10,
#        'referrerAmount': 10,
#        'currencySymbol': '€',
#        'currencyCode': 'EUR',
#        'inviteeSteps': 2,
#        'referrerSteps': 2,
#        'creditExpiry': 30,
#        'minimumOrderValue': 15,
#        'isActive': True},
#       'social': {'twitter': 'Deliveroo_BE',
#        'instagram': 'deliveroo_be',
#        'facebook': 'DeliverooBE',
#        'facebookShareId': 1166582576697917},
#       'blog': True,
#       'newsroomLink': 'https://be.deliveroo.news',
#       'careersLink': 'https://careers.deliveroo.be'},
#      {'id': 'fr',
#       'name': 'France',
#       'host': 'deliveroo.fr',
#       'isHidden': False,
#       'personalNames': 'first_last',
#       'roovite': {'inviteeAmount': 10,
#        'referrerAmount': 10,
#        'currencySymbol': '€',
#        'currencyCode': 'EUR',
#        'inviteeSteps': 4,
#        'referrerSteps': 4,
#        'creditExpiry': 30,
#        'minimumOrderValue': 18,
#        'isActive': True},
#       'social': {'twitter': 'Deliveroo_FR',
#        'instagram': 'deliveroo_fr',
#        'facebook': 'deliveroo.fr',
#        'facebookShareId': 513225688870020},
#       'blog': True,
#       'newsroomLink': 'https://fr.deliveroo.news',
#       'careersLink': 'https://careers.deliveroo.fr'},
#      {'id': 'de',
#       'name': 'Germany',
#       'host': 'deliveroo.de',
#       'isHidden': False,
#       'personalNames': 'first_last',
#       'roovite': {'inviteeAmount': 10,
#        'referrerAmount': 10,
#        'currencySymbol': '€',
#        'currencyCode': 'EUR',
#        'inviteeSteps': 4,
#        'referrerSteps': 4,
#        'creditExpiry': 30,
#        'minimumOrderValue': 20,
#        'isActive': True},
#       'social': {'twitter': 'Deliveroo',
#        'instagram': 'deliveroo',
#        'facebook': 'deliveroo.uk',
#        'facebookShareId': 317447631979255},
#       'blog': True,
#       'newsroomLink': 'https://de.deliveroo.news',
#       'careersLink': 'https://careers.deliveroo.de'},
#      {'id': 'hk',
#       'name': 'Hong Kong',
#       'host': 'deliveroo.hk',
#       'isHidden': False,
#       'personalNames': 'full_preferred',
#       'roovite': {'inviteeAmount': 100,
#        'referrerAmount': 100,
#        'currencySymbol': '$',
#        'currencyCode': 'HKD',
#        'inviteeSteps': 4,
#        'referrerSteps': 4,
#        'creditExpiry': 30,
#        'minimumOrderValue': 200,
#        'isActive': True},
#       'social': {'twitter': 'deliveroo_hk',
#        'instagram': 'deliveroo_hk',
#        'facebook': 'deliveroohk',
#        'facebookShareId': 1743215009299600},
#       'blog': False,
#       'newsroomLink': 'https://hk.deliveroo.news',
#       'careersLink': 'https://careers.deliveroo.hk'},
#      {'id': 'ie',
#       'name': 'Ireland',
#       'host': 'deliveroo.ie',
#       'isHidden': False,
#       'personalNames': 'first_last',
#       'roovite': {'inviteeAmount': 8,
#        'referrerAmount': 8,
#        'currencySymbol': '€',
#        'currencyCode': 'EUR',
#        'inviteeSteps': 4,
#        'referrerSteps': 4,
#        'creditExpiry': 30,
#        'minimumOrderValue': 20,
#        'isActive': True},
#       'social': {'twitter': 'Deliveroo_IE',
#        'instagram': 'deliveroo_ie',
#        'facebook': 'deliveroo.ie',
#        'facebookShareId': 892305060875730},
#       'blog': False,
#       'newsroomLink': 'https://ie.deliveroo.news',
#       'careersLink': 'https://careers.deliveroo.ie'},
#      {'id': 'it',
#       'name': 'Italy',
#       'host': 'deliveroo.it',
#       'isHidden': False,
#       'personalNames': 'first_last',
#       'roovite': {'inviteeAmount': 10,
#        'referrerAmount': 10,
#        'currencySymbol': '€',
#        'currencyCode': 'EUR',
#        'inviteeSteps': 4,
#        'referrerSteps': 4,
#        'creditExpiry': 30,
#        'minimumOrderValue': 20,
#        'isActive': True},
#       'social': {'twitter': 'deliveroo_italy',
#        'instagram': 'deliveroo_italy',
#        'facebook': 'DeliverooIT',
#        'facebookShareId': 1370379492977996},
#       'blog': True,
#       'newsroomLink': 'https://it.deliveroo.news',
#       'careersLink': 'https://careers.deliveroo.it'},
#      {'id': 'kw',
#       'name': 'Kuwait',
#       'host': 'deliveroo.com.kw',
#       'isHidden': False,
#       'personalNames': 'full_preferred',
#       'roovite': {'inviteeAmount': 5,
#        'referrerAmount': 5,
#        'currencySymbol': 'KD',
#        'currencyCode': 'KWD',
#        'inviteeSteps': 5,
#        'referrerSteps': 5,
#        'creditExpiry': 30,
#        'minimumOrderValue': 2.5,
#        'isActive': True},
#       'social': {'twitter': 'Deliveroo_KW',
#        'instagram': 'Deliveroo_KW',
#        'facebook': 'DeliverooKW',
#        'facebookShareId': None},
#       'blog': True,
#       'newsroomLink': 'https://ae.deliveroo.news',
#       'careersLink': 'https://careers.deliveroo.ae/'},
#      {'id': 'nl',
#       'name': 'Netherlands',
#       'host': 'deliveroo.nl',
#       'isHidden': False,
#       'personalNames': 'first_last',
#       'roovite': {'inviteeAmount': 8,
#        'referrerAmount': 8,
#        'currencySymbol': '€',
#        'currencyCode': 'EUR',
#        'inviteeSteps': 4,
#        'referrerSteps': 4,
#        'creditExpiry': 30,
#        'minimumOrderValue': 20,
#        'isActive': True},
#       'social': {'twitter': 'Deliveroo_NL',
#        'instagram': 'deliveroo_nl',
#        'facebook': 'Deliveroo-1475507472761064',
#        'facebookShareId': 1752144261738005},
#       'blog': True,
#       'newsroomLink': 'https://nl.deliveroo.news',
#       'careersLink': 'https://careers.deliveroo.nl'},
#      {'id': 'qa',
#       'name': 'Qatar',
#       'host': 'deliveroo.com.qa',
#       'isHidden': False,
#       'personalNames': 'full_preferred',
#       'roovite': {'inviteeAmount': 60,
#        'referrerAmount': 60,
#        'currencySymbol': 'QAR',
#        'currencyCode': 'QAR',
#        'inviteeSteps': 4,
#        'referrerSteps': 4,
#        'creditExpiry': 30,
#        'minimumOrderValue': 60,
#        'isActive': True},
#       'social': {'twitter': 'DeliverooQ',
#        'instagram': 'Deliveroo_QA',
#        'facebook': 'DeliverooQatar',
#        'facebookShareId': None},
#       'blog': True,
#       'newsroomLink': 'https://ae.deliveroo.news',
#       'careersLink': 'https://careers.deliveroo.ae/'},
#      {'id': 'sg',
#       'name': 'Singapore',
#       'host': 'deliveroo.com.sg',
#       'isHidden': False,
#       'personalNames': 'full_preferred',
#       'roovite': {'inviteeAmount': 16,
#        'referrerAmount': 16,
#        'currencySymbol': '$',
#        'currencyCode': 'SGD',
#        'inviteeSteps': 4,
#        'referrerSteps': 4,
#        'creditExpiry': 30,
#        'minimumOrderValue': 30,
#        'isActive': True},
#       'social': {'twitter': 'deliveroo_sg',
#        'instagram': 'deliveroo_sg',
#        'facebook': 'DeliverooSG',
#        'facebookShareId': 492740217591489},
#       'blog': True,
#       'newsroomLink': 'https://sg.deliveroo.news',
#       'careersLink': 'https://careers.deliveroo.com.sg'},
#      {'id': 'es',
#       'name': 'Spain',
#       'host': 'deliveroo.es',
#       'isHidden': False,
#       'personalNames': 'full_preferred',
#       'roovite': {'inviteeAmount': 10,
#        'referrerAmount': 10,
#        'currencySymbol': '€',
#        'currencyCode': 'EUR',
#        'inviteeSteps': 4,
#        'referrerSteps': 4,
#        'creditExpiry': 30,
#        'minimumOrderValue': 17,
#        'isActive': True},
#       'social': {'twitter': 'Deliveroo_ES',
#        'instagram': 'deliveroo_es',
#        'facebook': 'DeliverooES',
#        'facebookShareId': 854603238007092},
#       'blog': True,
#       'newsroomLink': 'https://es.deliveroo.news',
#       'careersLink': 'https://careers.deliveroo.es'},
#      {'id': 'tw',
#       'name': 'Taiwan',
#       'host': 'deliveroo.tw',
#       'isHidden': False,
#       'personalNames': 'full_preferred',
#       'roovite': {'inviteeAmount': 300,
#        'referrerAmount': 100,
#        'currencySymbol': '$',
#        'currencyCode': 'TWD',
#        'inviteeSteps': 4,
#        'referrerSteps': 2,
#        'creditExpiry': 30,
#        'minimumOrderValue': 350,
#        'isActive': True},
#       'social': {'twitter': 'Deliveroo',
#        'instagram': 'deliveroo',
#        'facebook': 'deliveroo.uk',
#        'facebookShareId': '669248419892694'},
#       'blog': True,
#       'newsroomLink': 'https://news.deliveroo.co.uk/',
#       'careersLink': 'https://careers.deliveroo.co.uk'},
#      {'id': 'ae',
#       'name': 'United Arab Emirates',
#       'host': 'deliveroo.ae',
#       'isHidden': False,
#       'personalNames': 'full_preferred',
#       'roovite': {'inviteeAmount': 60,
#        'referrerAmount': 60,
#        'currencySymbol': 'AED',
#        'currencyCode': 'AED',
#        'inviteeSteps': 4,
#        'referrerSteps': 4,
#        'creditExpiry': 30,
#        'minimumOrderValue': 90,
#        'isActive': True},
#       'social': {'twitter': 'Deliveroo_AE',
#        'instagram': 'deliveroo_ae',
#        'facebook': 'DeliverooDXB',
#        'facebookShareId': 1736503103270505},
#       'blog': True,
#       'newsroomLink': 'https://ae.deliveroo.news',
#       'careersLink': 'https://careers.deliveroo.ae'},
#      {'id': 'uk',
#       'name': 'United Kingdom',
#       'host': 'deliveroo.co.uk',
#       'isHidden': False,
#       'personalNames': 'first_last',
#       'roovite': {'inviteeAmount': 10,
#        'referrerAmount': 10,
#        'currencySymbol': '£',
#        'currencyCode': 'GBP',
#        'inviteeSteps': 4,
#        'referrerSteps': 4,
#        'creditExpiry': 30,
#        'minimumOrderValue': 20,
#        'isActive': True},
#       'social': {'twitter': 'Deliveroo',
#        'instagram': 'deliveroo',
#        'facebook': 'deliveroo.uk',
#        'facebookShareId': 669248419892694},
#       'blog': True,
#       'newsroomLink': 'https://uk.deliveroo.news/',
#       'careersLink': 'https://careers.deliveroo.co.uk'}],
#     'features': {'cht_175_improved_scroll_tracking_on_home': True,
#      'cwa_client_side_routing_config_call': True,
#      'collect_245_clients': True,
#      'display_dob_in_user_profile': True,
#      'group_ordering': True,
#      'is_consumer_flow_active': True,
#      'menu_scroll_tracking': True,
#      'new_menu_search_enabled': True,
#      'use_order_history_api_consumer_orders_v1': True,
#      'white_label_brand_gtm_enabled': True,
#      'web_credits_offers_endpoint_enabled': True,
#      'csr_investors_page': True,
#      'new_web_address_flow_enabled': True,
#      'cuisines_index_storyblok': True,
#      'shareable_order_status_web': True,
#      'deliveroo_for_work_enabled': True,
#      'fex_516': True,
#      'fex_75_success_login_banner': True,
#      'gdpr_privacy_policy': True,
#      'google_signin_enabled': True,
#      'en_572_clients_enabled': True,
#      'brands_footer_link_enabled': True,
#      'cuisines_footer_link_enabled': True,
#      'cuisine_landing_pages_restaurants_section': True,
#      'snux_714_seo_audit': True,
#      'pup_18_clients': True,
#      'hr_talent_page': True,
#      'web_info_banner': True,
#      'rs_11126_nandos_pricing_survey': True,
#      'new_market_locale_pending_ar_kw': True,
#      'onetrust_cookie_consent': True,
#      'loy_773_onetrust_new_workflow_web': True,
#      'web_order_tracker_show_missed_call_modal': True,
#      'tds_service_redemption': True,
#      'pickup_popup_disabled': True,
#      'enable_web_consumer_erasure': True,
#      'post_order_modal_download_the_app_enabled': True,
#      'project_rainfall_contact_links_enabled': True,
#      'project_rainfall_enabled': True,
#      'project_rainfall_enabled_unlink': True,
#      'sms_verification_account_creation': True,
#      'review_reply_escalate_to_zendesk': True,
#      'rider-positive-handover-killswitch': True,
#      'sca_support_enabled': True,
#      'cht_1934_show_discounted_price_when_item_plus_basket_meet_mov': True,
#      'social_login_web': True,
#      'web_sms_verification_on_signup': True},
#     'experiments': {'cwa_client_side_routing_2': 'control',
#      'co_search_recent_searches_web': 'feature',
#      'fex_486': 'feature',
#      'cht_391_home_remove_fulfillment_methods': 'feature',
#      'mvt_1103_cp_hide_delivery_fee_web': 'feature',
#      'mvt_1115_web': 'feature',
#      'mvt_1146_co_search_web': 'feature',
#      'mvt_1172_homepage_layout_updates': 'on',
#      'mvt_1189_co_homepage_here_to_deliver': 'feature',
#      'mvt_894_sms_on_social_copy': 'control',
#      'mvt_homepage_storyblok_test': 'homepage_variant_a',
#      'web_postcode_mvt_for_country': 'use_geohashes',
#      'rs_work_with_us_dropdown': 'work_with_us',
#      'co_web_funnel_holdout': 'out_of_experiment'},
#     'rooStickyGuid': '823e88cc-74fe-4626-af25-728ede415373',
#     'stripePublishableKey': 'pk_live_Xon38nmuPwMk6T5SAfyPglmv'},
#    'creditRedemption': {'loading': False},
#    'corporateInvitation': {'loading': False,
#     'csrfToken': '',
#     'acceptSuccess': False,
#     'invitation': {'inviteId': '',
#      'inviteCorporation': '',
#      'inviteName': '',
#      'inviteEmail': '',
#      'inviteUsed': False,
#      'inviteExpired': False}},
#    'cuisine': {'loading': False},
#    'favourites': {'favouritesList': {'defaultList': [],
#      'layoutGroups': [],
#      'layoutTabs': [],
#      'meta': {'trackingId': ''}},
#     'errors': {'network': None, 'graphql': []},
#     'trackedFavourites': {},
#     'isLoading': False,
#     'isListLoading': False,
#     'lastUpdatedFavourite': {},
#     'isModalOpen': False,
#     'querySource': '',
#     'isToastOpen': False,
#     'toastAction': ''},
#    'home': {'feed': {'results': {'subheader': '', 'data': []},
#      'fulfillmentMethods': [],
#      'sort': [],
#      'filters': [],
#      'searchResults': [],
#      'searchResultsMeta': {},
#      'recentSearches': [],
#      'appliedFilters': [],
#      'meta': {},
#      'fulfillmentTimes': {},
#      'loading': False,
#      'loadingSearch': False,
#      'showMapButton': False,
#      'isCopyVoucherCodeToastOpen': False,
#      'modal': {},
#      'overlays': [],
#      'applyRateLimit': False},
#     'filters': {'location': {'geohash': '',
#       'postcode': '',
#       'city': '',
#       'neighborhood': ''},
#      'fulfillmentMethod': '',
#      'fulfillmentTime': '',
#      'deliveryTime': '',
#      'selectedFilters': {},
#      'query': '',
#      'showDateTimeModal': False,
#      'showLogisticsModal': False},
#     'map': {'cards': [],
#      'hasError': False,
#      'isLoading': False,
#      'isOpen': False,
#      'latLngBounds': None,
#      'pins': [],
#      'selectedRestaurantId': ''}},
#    'homepageFeaturedContent': {'collections': [],
#     'restaurants': [],
#     'landingPages': []},
#    'landingPage': {'loading': False},
#    'location': {'search': {'loading': False,
#      'focused': False,
#      'error': None,
#      'showModal': False,
#      'showVoteAreaModal': False,
#      'canBasketDeliverToLocation': False},
#     'recentAddresses': {'loading': False, 'error': None, 'locations': []},
#     'places': {'loading': False,
#      'isLocating': False,
#      'hasPinMoved': False,
#      'suggestions': [],
#      'loadingSuggestions': False}},
#    'mealCard': {'issuers': [], 'showModal': False, 'error': None},
#    'notification': {'showNotification': False, 'message': None, 'type': None},
#    'order': {'help': {'error': None, 'loading': False, 'orderHelpModal': {}},
#     'helpFeedback': {'error': None, 'loading': False},
#     'status': {'error': None,
#      'failedAttempts': 0,
#      'loading': False,
#      'statuses': {},
#      'shareModal': {'error': None, 'loading': False}},
#     'statuses': {},
#     'history': {'error': None,
#      'loading': False,
#      'orders': [],
#      'orderHistoryPage': 0,
#      'showLoadMoreButton': True,
#      'selectedOrderId': None},
#     'rewardCard': {'loading': False, 'loaded': False},
#     'challenges': {'loading': False, 'loaded': False, 'available': False}},
#    'referral': {'loading': False},
#    'request': {'host': 'https://deliveroo.co.uk',
#     'alternateUrls': [],
#     'userPreferences': {},
#     'apiFailures': [],
#     'currentUrl': "/menu/London/king's-cross/10709-kfc-kings-cross-uk?day=today&postcode=EC&time=ASAP",
#     'currentQuery': {'day': 'today',
#      'postcode': 'EC',
#      'time': 'ASAP',
#      'city': 'London',
#      'neighborhood': "king's-cross",
#      'restaurant': '10709-kfc-kings-cross-uk'},
#     'config': {'country_info': {'au': {'contact': {'support': {'phone': '+61 283 208 541',
#          'email': 'support@deliveroo.com.au',
#          'corporate_phone': '+61 283 208 541',
#          'corporate_email': 'support@deliveroo.com.au'},
#         'social': {'twitter': 'Deliveroo_AU',
#          'instagram': 'deliveroo_au',
#          'facebook': 'deliverooau',
#          'facebook_id': '744811542290829',
#          'facebook_share_id': 153825428355668},
#         'feedback': {'ios': {'email': 'support@deliveroo.com.au'},
#          'android': {'email': 'support@deliveroo.com.au'}},
#         'blog': True,
#         'newsroom_link': 'https://au.deliveroo.news',
#         'careers_link': 'https://careers.deliveroo.com.au'},
#        'hidden': False,
#        'host': 'deliveroo.com.au',
#        'iso_alpha2_code': 'AU',
#        'localized_name': 'Australia',
#        'personal_names': 'first_last',
#        'roovite': {'amount': 12,
#         'invitee_amount': 12,
#         'referrer_amount': 12,
#         'currency_symbol': '$',
#         'currency_code': 'AUD',
#         'credit_expiry': 30,
#         'minimum_order_value': 20,
#         'message': "Refer a friend and get $12 off across your next 4 orders. They'll get $12 off across their first 4 orders!",
#         'is_active': True,
#         'invitee_steps': 4,
#         'referrer_steps': 4}},
#       'be': {'contact': {'support': {'phone': '+32 2 895 40 05',
#          'email': 'hello@deliveroo.be',
#          'corporate_phone': '+32 28 95 40 50',
#          'corporate_email': 'corporate@deliveroo.be'},
#         'social': {'twitter': 'Deliveroo_BE',
#          'instagram': 'deliveroo_be',
#          'facebook': 'DeliverooBE',
#          'facebook_id': '867081423367796',
#          'facebook_share_id': 1166582576697917},
#         'feedback': {'ios': {'email': 'hello@deliveroo.be'},
#          'android': {'email': 'hello@deliveroo.be'}},
#         'blog': True,
#         'newsroom_link': 'https://be.deliveroo.news',
#         'careers_link': 'https://careers.deliveroo.be'},
#        'hidden': False,
#        'host': 'deliveroo.be',
#        'iso_alpha2_code': 'BE',
#        'localized_name': 'Belgium',
#        'personal_names': 'first_last',
#        'roovite': {'amount': 10,
#         'invitee_amount': 10,
#         'referrer_amount': 10,
#         'currency_symbol': '€',
#         'currency_code': 'EUR',
#         'credit_expiry': 30,
#         'minimum_order_value': 15,
#         'message': "Refer a friend and get €10 off across your next 2 orders. They'll get €10 off across their first 2 orders!",
#         'is_active': True,
#         'invitee_steps': 2,
#         'referrer_steps': 2}},
#       'fr': {'contact': {'support': {'phone': '+33 9 77 55 03 30',
#          'email': 'support@deliveroo.fr',
#          'corporate_phone': '+33 5 47 48 48 19',
#          'corporate_email': 'cscorporate@deliveroo.fr'},
#         'social': {'twitter': 'Deliveroo_FR',
#          'instagram': 'deliveroo_fr',
#          'facebook': 'deliveroo.fr',
#          'facebook_id': '298497216936972',
#          'facebook_share_id': 513225688870020},
#         'feedback': {'ios': {'email': 'hello@deliveroo.fr'},
#          'android': {'email': 'hello@deliveroo.fr'}},
#         'blog': True,
#         'newsroom_link': 'https://fr.deliveroo.news',
#         'careers_link': 'https://careers.deliveroo.fr'},
#        'hidden': False,
#        'host': 'deliveroo.fr',
#        'iso_alpha2_code': 'FR',
#        'localized_name': 'France',
#        'personal_names': 'first_last',
#        'roovite': {'amount': 10,
#         'invitee_amount': 10,
#         'referrer_amount': 10,
#         'currency_symbol': '€',
#         'currency_code': 'EUR',
#         'credit_expiry': 30,
#         'minimum_order_value': 18,
#         'message': "Refer a friend and get €10 off across your next 4 orders. They'll get €10 off across their first 4 orders!",
#         'is_active': True,
#         'invitee_steps': 4,
#         'referrer_steps': 4}},
#       'de': {'contact': {'support': {'phone': '+49 3022 403 0200',
#          'email': 'support@deliveroo.de',
#          'corporate_phone': '+49 3022 403 0200',
#          'corporate_email': 'firmen@deliveroo.de'},
#         'social': {'twitter': 'Deliveroo',
#          'instagram': 'deliveroo',
#          'facebook': 'deliveroo.uk',
#          'facebook_id': '298497216936972',
#          'facebook_share_id': 317447631979255},
#         'feedback': {'ios': {'email': 'support@deliveroo.de'},
#          'android': {'email': 'support@deliveroo.de'}},
#         'blog': True,
#         'newsroom_link': 'https://de.deliveroo.news',
#         'careers_link': 'https://careers.deliveroo.de'},
#        'hidden': False,
#        'host': 'deliveroo.de',
#        'iso_alpha2_code': 'DE',
#        'localized_name': 'Germany',
#        'personal_names': 'first_last',
#        'roovite': {'amount': 10,
#         'invitee_amount': 10,
#         'referrer_amount': 10,
#         'currency_symbol': '€',
#         'currency_code': 'EUR',
#         'credit_expiry': 30,
#         'minimum_order_value': 20,
#         'message': "Refer a friend and get €10 off across your next 4 orders. They'll get €10 off across their first 4 orders!",
#         'is_active': True,
#         'invitee_steps': 4,
#         'referrer_steps': 4}},
#       'hk': {'contact': {'support': {'phone': '+852 5808 8718',
#          'email': 'support@deliveroo.hk',
#          'corporate_phone': '+852 5808 8730',
#          'corporate_email': 'support@deliveroo.hk'},
#         'social': {'twitter': 'deliveroo_hk',
#          'instagram': 'deliveroo_hk',
#          'facebook': 'deliveroohk',
#          'facebook_id': '1641536502783965',
#          'facebook_share_id': 1743215009299600},
#         'feedback': {'ios': {'email': 'support@deliveroo.hk'},
#          'android': {'email': 'support@deliveroo.hk'}},
#         'blog': False,
#         'newsroom_link': 'https://hk.deliveroo.news',
#         'careers_link': 'https://careers.deliveroo.hk'},
#        'hidden': False,
#        'host': 'deliveroo.hk',
#        'iso_alpha2_code': 'HK',
#        'localized_name': 'Hong Kong',
#        'personal_names': 'full_preferred',
#        'roovite': {'amount': 100,
#         'invitee_amount': 100,
#         'referrer_amount': 100,
#         'currency_symbol': '$',
#         'currency_code': 'HKD',
#         'credit_expiry': 30,
#         'minimum_order_value': 200,
#         'message': "Refer a friend and get $100 off across your next 4 orders. They'll get $100 off across their first 4 orders!",
#         'is_active': True,
#         'invitee_steps': 4,
#         'referrer_steps': 4}},
#       'ie': {'contact': {'support': {'phone': '+353 1 526 8611',
#          'email': 'support@deliveroo.ie',
#          'corporate_phone': '+353 1 526 8611',
#          'corporate_email': 'corporatesupport@deliveroo.ie'},
#         'social': {'twitter': 'Deliveroo_IE',
#          'instagram': 'deliveroo_ie',
#          'facebook': 'deliveroo.ie',
#          'facebook_id': '298497216936972',
#          'facebook_share_id': 892305060875730},
#         'feedback': {'ios': {'email': 'support@deliveroo.ie'},
#          'android': {'email': 'support@deliveroo.ie'}},
#         'blog': False,
#         'newsroom_link': 'https://ie.deliveroo.news',
#         'careers_link': 'https://careers.deliveroo.ie'},
#        'hidden': False,
#        'host': 'deliveroo.ie',
#        'iso_alpha2_code': 'IE',
#        'localized_name': 'Ireland',
#        'personal_names': 'first_last',
#        'roovite': {'amount': 8,
#         'invitee_amount': 8,
#         'referrer_amount': 8,
#         'currency_symbol': '€',
#         'currency_code': 'EUR',
#         'credit_expiry': 30,
#         'minimum_order_value': 20,
#         'message': "Refer a friend and get €8 off across your next 4 orders. They'll get €8 off across their first 4 orders!",
#         'is_active': True,
#         'invitee_steps': 4,
#         'referrer_steps': 4}},
#       'it': {'contact': {'support': {'phone': '+390230578330',
#          'email': 'support@deliveroo.it',
#          'corporate_phone': '+390230578330',
#          'corporate_email': 'aziende@deliveroo.it'},
#         'social': {'twitter': 'deliveroo_italy',
#          'instagram': 'deliveroo_italy',
#          'facebook': 'DeliverooIT',
#          'facebook_id': '151392178542597',
#          'facebook_share_id': 1370379492977996},
#         'feedback': {'ios': {'email': 'support@deliveroo.it'},
#          'android': {'email': 'support@deliveroo.it'}},
#         'blog': True,
#         'newsroom_link': 'https://it.deliveroo.news',
#         'careers_link': 'https://careers.deliveroo.it'},
#        'hidden': False,
#        'host': 'deliveroo.it',
#        'iso_alpha2_code': 'IT',
#        'localized_name': 'Italy',
#        'personal_names': 'first_last',
#        'roovite': {'amount': 10,
#         'invitee_amount': 10,
#         'referrer_amount': 10,
#         'currency_symbol': '€',
#         'currency_code': 'EUR',
#         'credit_expiry': 30,
#         'minimum_order_value': 20,
#         'message': "Refer a friend and get €10 off across your next 4 orders. They'll get €10 off across their first 4 orders!",
#         'is_active': True,
#         'invitee_steps': 4,
#         'referrer_steps': 4}},
#       'kw': {'contact': {'support': {'phone': '00965 22270142',
#          'email': 'support@deliveroo.com.kw',
#          'corporate_phone': None,
#          'corporate_email': None},
#         'social': {'twitter': 'Deliveroo_KW',
#          'instagram': 'Deliveroo_KW',
#          'facebook': 'DeliverooKW',
#          'facebook_id': '428223824371913',
#          'facebook_share_id': None},
#         'feedback': {'ios': {'email': 'ios@deliveroo.co.uk'},
#          'android': {'email': 'android@deliveroo.co.uk'}},
#         'blog': True,
#         'newsroom_link': 'https://ae.deliveroo.news',
#         'careers_link': 'https://careers.deliveroo.ae/'},
#        'hidden': False,
#        'host': 'deliveroo.com.kw',
#        'iso_alpha2_code': 'KW',
#        'localized_name': 'Kuwait',
#        'personal_names': 'full_preferred',
#        'roovite': {'amount': 5,
#         'invitee_amount': 5,
#         'referrer_amount': 5,
#         'currency_symbol': 'KD',
#         'currency_code': 'KWD',
#         'credit_expiry': 30,
#         'minimum_order_value': 2.5,
#         'message': "Refer a friend and get KD\xa05 off across your next 5 orders. They'll get KD\xa05 off across their first 5 orders!",
#         'is_active': True,
#         'invitee_steps': 5,
#         'referrer_steps': 5}},
#       'nl': {'contact': {'support': {'phone': '+31 88 3354837',
#          'email': 'klantenservice@deliveroo.nl',
#          'corporate_phone': '+31 88 3354837',
#          'corporate_email': 'corporate@deliveroo.nl'},
#         'social': {'twitter': 'Deliveroo_NL',
#          'instagram': 'deliveroo_nl',
#          'facebook': 'Deliveroo-1475507472761064',
#          'facebook_id': '1475507472761064',
#          'facebook_share_id': 1752144261738005},
#         'feedback': {'ios': {'email': 'klantenservice@deliveroo.nl'},
#          'android': {'email': 'klantenservice@deliveroo.nl'}},
#         'blog': True,
#         'newsroom_link': 'https://nl.deliveroo.news',
#         'careers_link': 'https://careers.deliveroo.nl'},
#        'hidden': False,
#        'host': 'deliveroo.nl',
#        'iso_alpha2_code': 'NL',
#        'localized_name': 'Netherlands',
#        'personal_names': 'first_last',
#        'roovite': {'amount': 8,
#         'invitee_amount': 8,
#         'referrer_amount': 8,
#         'currency_symbol': '€',
#         'currency_code': 'EUR',
#         'credit_expiry': 30,
#         'minimum_order_value': 20,
#         'message': "Refer a friend and get €8 off across your next 4 orders. They'll get €8 off across their first 4 orders!",
#         'is_active': True,
#         'invitee_steps': 4,
#         'referrer_steps': 4}},
#       'qa': {'contact': {'support': {'phone': '+97444196557',
#          'email': 'support@deliveroo.com.qa',
#          'corporate_phone': None,
#          'corporate_email': None},
#         'social': {'twitter': 'DeliverooQ',
#          'instagram': 'Deliveroo_QA',
#          'facebook': 'DeliverooQatar',
#          'facebook_id': '428223824371913',
#          'facebook_share_id': None},
#         'feedback': {'ios': {'email': 'ios-qa@deliveroo.com.qa'},
#          'android': {'email': 'android@deliveroo.co.uk'}},
#         'blog': True,
#         'newsroom_link': 'https://ae.deliveroo.news',
#         'careers_link': 'https://careers.deliveroo.ae/'},
#        'hidden': False,
#        'host': 'deliveroo.com.qa',
#        'iso_alpha2_code': 'QA',
#        'localized_name': 'Qatar',
#        'personal_names': 'full_preferred',
#        'roovite': {'amount': 60,
#         'invitee_amount': 60,
#         'referrer_amount': 60,
#         'currency_symbol': 'QAR',
#         'currency_code': 'QAR',
#         'credit_expiry': 30,
#         'minimum_order_value': 60,
#         'message': "Refer a friend and get QAR\xa060 off across your next 4 orders. They'll get QAR\xa060 off across their first 4 orders!",
#         'is_active': True,
#         'invitee_steps': 4,
#         'referrer_steps': 4}},
#       'sg': {'contact': {'support': {'phone': '+65 3163 7074',
#          'email': 'support@deliveroo.com.sg',
#          'corporate_phone': '+65 6813 3113',
#          'corporate_email': 'corporate@deliveroo.com.sg'},
#         'social': {'twitter': 'deliveroo_sg',
#          'instagram': 'deliveroo_sg',
#          'facebook': 'DeliverooSG',
#          'facebook_id': '298497216936972',
#          'facebook_share_id': 492740217591489},
#         'feedback': {'ios': {'email': 'support@deliveroo.com.sg'},
#          'android': {'email': 'support@deliveroo.com.sg'}},
#         'blog': True,
#         'newsroom_link': 'https://sg.deliveroo.news',
#         'careers_link': 'https://careers.deliveroo.com.sg'},
#        'hidden': False,
#        'host': 'deliveroo.com.sg',
#        'iso_alpha2_code': 'SG',
#        'localized_name': 'Singapore',
#        'personal_names': 'full_preferred',
#        'roovite': {'amount': 16,
#         'invitee_amount': 16,
#         'referrer_amount': 16,
#         'currency_symbol': '$',
#         'currency_code': 'SGD',
#         'credit_expiry': 30,
#         'minimum_order_value': 30,
#         'message': "Refer a friend and get $16 off across your next 4 orders. They'll get $16 off across their first 4 orders!",
#         'is_active': True,
#         'invitee_steps': 4,
#         'referrer_steps': 4}},
#       'es': {'contact': {'support': {'phone': '+34 917 69 3660',
#          'email': 'atencion@deliveroo.es',
#          'corporate_phone': '+34 917 69 3660',
#          'corporate_email': 'atencion@deliveroo.es'},
#         'social': {'twitter': 'Deliveroo_ES',
#          'instagram': 'deliveroo_es',
#          'facebook': 'DeliverooES',
#          'facebook_id': '920985947972439',
#          'facebook_share_id': 854603238007092},
#         'feedback': {'ios': {'email': 'atencion@deliveroo.es'},
#          'android': {'email': 'atencion@deliveroo.es'}},
#         'blog': True,
#         'newsroom_link': 'https://es.deliveroo.news',
#         'careers_link': 'https://careers.deliveroo.es'},
#        'hidden': False,
#        'host': 'deliveroo.es',
#        'iso_alpha2_code': 'ES',
#        'localized_name': 'Spain',
#        'personal_names': 'full_preferred',
#        'roovite': {'amount': 10,
#         'invitee_amount': 10,
#         'referrer_amount': 10,
#         'currency_symbol': '€',
#         'currency_code': 'EUR',
#         'credit_expiry': 30,
#         'minimum_order_value': 17,
#         'message': "Refer a friend and get €10 off across your next 4 orders. They'll get €10 off across their first 4 orders!",
#         'is_active': True,
#         'invitee_steps': 4,
#         'referrer_steps': 4}},
#       'tw': {'contact': {'support': {'phone': '+886 2 5594 1035',
#          'email': 'support@deliveroo.tw',
#          'corporate_phone': None,
#          'corporate_email': None},
#         'social': {'twitter': 'Deliveroo',
#          'instagram': 'deliveroo',
#          'facebook': 'deliveroo.uk',
#          'facebook_id': '298497216936972',
#          'facebook_share_id': '669248419892694'},
#         'feedback': {'ios': {'email': 'support@deliveroo.tw'},
#          'android': {'email': 'support@deliveroo.tw'}},
#         'blog': True,
#         'newsroom_link': 'https://news.deliveroo.co.uk/',
#         'careers_link': 'https://careers.deliveroo.co.uk'},
#        'hidden': False,
#        'host': 'deliveroo.tw',
#        'iso_alpha2_code': 'TW',
#        'localized_name': 'Taiwan',
#        'personal_names': 'full_preferred',
#        'roovite': {'amount': 300,
#         'invitee_amount': 300,
#         'referrer_amount': 100,
#         'currency_symbol': '$',
#         'currency_code': 'TWD',
#         'credit_expiry': 30,
#         'minimum_order_value': 350,
#         'message': "Refer a friend and get $100 off across your next 2 orders. They'll get $300 off across their first 4 orders!",
#         'is_active': True,
#         'invitee_steps': 4,
#         'referrer_steps': 2}},
#       'ae': {'contact': {'support': {'phone': '+971 451 26268',
#          'email': 'support@deliveroo.ae',
#          'corporate_phone': '+971 451 26268',
#          'corporate_email': 'support@deliveroo.ae'},
#         'social': {'twitter': 'Deliveroo_AE',
#          'instagram': 'deliveroo_ae',
#          'facebook': 'DeliverooDXB',
#          'facebook_id': '760564330715141',
#          'facebook_share_id': 1736503103270505},
#         'feedback': {'ios': {'email': 'support@deliveroo.ae'},
#          'android': {'email': 'support@deliveroo.ae'}},
#         'blog': True,
#         'newsroom_link': 'https://ae.deliveroo.news',
#         'careers_link': 'https://careers.deliveroo.ae'},
#        'hidden': False,
#        'host': 'deliveroo.ae',
#        'iso_alpha2_code': 'AE',
#        'localized_name': 'United Arab Emirates',
#        'personal_names': 'full_preferred',
#        'roovite': {'amount': 60,
#         'invitee_amount': 60,
#         'referrer_amount': 60,
#         'currency_symbol': 'AED',
#         'currency_code': 'AED',
#         'credit_expiry': 30,
#         'minimum_order_value': 90,
#         'message': "Refer a friend and get AED\xa060 off across your next 4 orders. They'll get AED\xa060 off across their first 4 orders!",
#         'is_active': True,
#         'invitee_steps': 4,
#         'referrer_steps': 4}},
#       'uk': {'contact': {'support': {'phone': '+44 203 699 9977',
#          'email': 'support@deliveroo.co.uk',
#          'corporate_phone': '+44 203 699 9978',
#          'corporate_email': 'corporatesupport@deliveroo.co.uk'},
#         'social': {'twitter': 'Deliveroo',
#          'instagram': 'deliveroo',
#          'facebook': 'deliveroo.uk',
#          'facebook_id': '298497216936972',
#          'facebook_share_id': 669248419892694},
#         'feedback': {'ios': {'email': 'ios@deliveroo.co.uk'},
#          'android': {'email': 'android@deliveroo.co.uk'}},
#         'blog': True,
#         'newsroom_link': 'https://uk.deliveroo.news/',
#         'careers_link': 'https://careers.deliveroo.co.uk'},
#        'hidden': False,
#        'host': 'deliveroo.co.uk',
#        'iso_alpha2_code': 'GB',
#        'localized_name': 'United Kingdom',
#        'personal_names': 'first_last',
#        'roovite': {'amount': 10,
#         'invitee_amount': 10,
#         'referrer_amount': 10,
#         'currency_symbol': '£',
#         'currency_code': 'GBP',
#         'credit_expiry': 30,
#         'minimum_order_value': 20,
#         'message': "Refer a friend and get £10 off across your next 4 orders. They'll get £10 off across their first 4 orders!",
#         'is_active': True,
#         'invitee_steps': 4,
#         'referrer_steps': 4}}},
#      'stripe': {'publishable_key': 'pk_live_Xon38nmuPwMk6T5SAfyPglmv'},
#      'ios_app': {'min_version': '3.176.0', 'min_prompt_version': '3.180.0'},
#      'android_app': {'min_version': '3.118.1',
#       'min_prompt_version': '3.124.0'},
#      'features': {'cht_175_improved_scroll_tracking_on_home': True,
#       'cwa_client_side_routing_config_call': True,
#       'collect_245_clients': True,
#       'display_dob_in_user_profile': True,
#       'group_ordering': True,
#       'is_consumer_flow_active': True,
#       'menu_scroll_tracking': True,
#       'new_menu_search_enabled': True,
#       'use_order_history_api_consumer_orders_v1': True,
#       'white_label_brand_gtm_enabled': True,
#       'web_credits_offers_endpoint_enabled': True,
#       'csr_investors_page': True,
#       'new_web_address_flow_enabled': True,
#       'cuisines_index_storyblok': True,
#       'shareable_order_status_web': True,
#       'deliveroo_for_work_enabled': True,
#       'fex_516': True,
#       'fex_75_success_login_banner': True,
#       'gdpr_privacy_policy': True,
#       'google_signin_enabled': True,
#       'en_572_clients_enabled': True,
#       'brands_footer_link_enabled': True,
#       'cuisines_footer_link_enabled': True,
#       'cuisine_landing_pages_restaurants_section': True,
#       'snux_714_seo_audit': True,
#       'pup_18_clients': True,
#       'hr_talent_page': True,
#       'web_info_banner': True,
#       'rs_11126_nandos_pricing_survey': True,
#       'new_market_locale_pending_ar_kw': True,
#       'onetrust_cookie_consent': True,
#       'loy_773_onetrust_new_workflow_web': True,
#       'web_order_tracker_show_missed_call_modal': True,
#       'tds_service_redemption': True,
#       'pickup_popup_disabled': True,
#       'enable_web_consumer_erasure': True,
#       'post_order_modal_download_the_app_enabled': True,
#       'project_rainfall_contact_links_enabled': True,
#       'project_rainfall_enabled': True,
#       'project_rainfall_enabled_unlink': True,
#       'sms_verification_account_creation': True,
#       'review_reply_escalate_to_zendesk': True,
#       'rider-positive-handover-killswitch': True,
#       'sca_support_enabled': True,
#       'cht_1934_show_discounted_price_when_item_plus_basket_meet_mov': True,
#       'social_login_web': True,
#       'web_sms_verification_on_signup': True},
#      'ab_tests': {'cwa_client_side_routing_2': 'control',
#       'co_search_recent_searches_web': 'feature',
#       'fex_486': 'feature',
#       'cht_391_home_remove_fulfillment_methods': 'feature',
#       'mvt_1103_cp_hide_delivery_fee_web': 'feature',
#       'mvt_1115_web': 'feature',
#       'mvt_1146_co_search_web': 'feature',
#       'mvt_1172_homepage_layout_updates': 'on',
#       'mvt_1189_co_homepage_here_to_deliver': 'feature',
#       'mvt_894_sms_on_social_copy': 'control',
#       'mvt_homepage_storyblok_test': 'homepage_variant_a',
#       'web_postcode_mvt_for_country': 'use_geohashes',
#       'rs_work_with_us_dropdown': 'work_with_us',
#       'co_web_funnel_holdout': 'out_of_experiment'},
#      'user': {},
#      'places_api': {'key': 'abcdef',
#       'base_url': 'https://deliveroo.co.uk/orderapp/v1/google_places_proxy/v1/'},
#      'partnerships': [],
#      'sticky_guid': '823e88cc-74fe-4626-af25-728ede415373'},
#     'browseData': None,
#     'country': {'tld': 'uk',
#      'host': 'deliveroo.co.uk',
#      'isoCode': 'GB',
#      'languages': ['en'],
#      'examplePostcode': 'EC4R 3TE',
#      'postcodeSearch': True,
#      'riderInviteLink': True,
#      'restaurantsHomepageUrl': {'default': 'https://restaurants.deliveroo.com/'},
#      'appRatings': {'itunesCount': '482,088',
#       'itunesRating': 4.6,
#       'googleCount': '131,970',
#       'googleRating': 4.3},
#      'enableDeliverooForBusiness': True,
#      'salesforceKey': 'UK',
#      'isHidden': False,
#      'callingCode': 44},
#     'ip': '192.54.222.141',
#     'locale': 'en',
#     'rooBotScore': '1',
#     'rooGuid': '823e88cc-74fe-4626-af25-728ede415373',
#     'rooSessionGuid': '4067707c-0113-4188-94ae-5fbdcb792468',
#     'seenCookieMessage': False,
#     'theme': {'className': '__theme-default', 'name': 'default'},
#     'unverifiedUserId': None,
#     'userAgent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.63 Safari/537.36',
#     'userAgentFamily': 'Chrome',
#     'userAgentMajor': '102',
#     'userAgentMinor': '0',
#     'userAgentPatch': '5005',
#     'isMaybeBot': False,
#     'whiteLabel': {},
#     'debugErrorId': '23746e57-48d4-43d1-8185-375f54a36087'},
#    'staticPage': {'error': None},
#    'subscriptions': {'loading': False,
#     'benefits': [],
#     'plans': [],
#     'strings': {},
#     'creation': {'inProgress': False, 'successful': False, 'error': None},
#     'upsells': {'loading': False, 'error': None, 'restaurantListUpsell': None},
#     'stripePaymentCardCreation': {'inProgress': False, 'error': None},
#     'amazonPrimeOffer': {'sharedData': {},
#      'landingScreen': {},
#      'switchPlanScreen': {},
#      'upgradeToPrimeScreen': {}},
#     'partnershipOffer': {'error': False,
#      'sharedData': {},
#      'tiers': [],
#      'benefits': []}},
#    'user': {'loading': False,
#     'isLoggedIn': False,
#     'mealCards': [],
#     'paymentToken': None,
#     'paymentTokens': [],
#     'paymentTokensErrors': None,
#     'paymentTokensLoading': False,
#     'isPlusEligible': False,
#     'isSubscriber': False,
#     'showRewards': False,
#     'challenges': None,
#     'subscriptionOfferUname': None,
#     'subscriptionDrnId': None,
#     'subscriptionLinking': None,
#     'roovite': {'showModal': False}},
#    'voteArea': {'submitted': False, 'error': None},
#    'voucher': {'isLoading': False},
#    'orderRating': {'errors': {'network': None, 'graphql': []},
#     'isModalOpen': False,
#     'isLoading': False,
#     'isManageModalOpen': False,
#     'manageReview': {},
#     'trackedReviews': {}},
#    'orderReviews': {'errors': {'graphql': []},
#     'layouts': [],
#     'meta': {'trackingId': '', 'partnerDrnId': '', 'appliedSort': ''},
#     'hiddenReviews': {},
#     'isHandlingAction': False,
#     'isModalOpen': False,
#     'isLoading': False,
#     'isToastOpen': False,
#     'toastActionSource': 'default',
#     'pagination': {'limit': 50, 'offset': 0},
#     'viewedModalId': '',
#     'selectedParams': []},
#    'menuPage': {'menu': {'meta': {'metatags': {'title': "KFC - Kings Cross delivery from King's Cross - Order with Deliveroo",
#        'titleSocial': 'KFC - Kings Cross on Deliveroo',
#        'description': 'The best local restaurants and takeaways are here to deliver. Order on Deliveroo today!',
#        'descriptionSocial': "Serving up amazing food, KFC - Kings Cross sits in the heart of King's Cross. With dishes you're guaranteed to love, order now for delivery within 32 minutes",
#        'image': 'https://rs-menus-api.roocdn.com/images/6ab50559-2fdd-4ad0-ae6c-5c9de8cd9cd7/image.jpeg?width=1200&height=630&fit=crop',
# ...
#      "Please enter an address to find out if there's a %(restaurantName)s near you.": ["Please enter an address to find out if there's a %(restaurantName)s near you."],
#      'Please enter your email address': ['Please enter your email address'],
#      "Please note we don't currently accept orders over the phone - so if you'd like to place an order, please place it online. The number above is for customer service enquiries only.": ["Please note we don't currently accept orders over the phone - so if you'd like to place an order, please place it online. The number above is for customer service enquiries only."],
#      'Please select an address from the dropdown.': ['Please select an address from the dropdown.'],
#      'Please try again.': ['Please try again.'],
#      'plus.account.rewards.main_title': ['Rewards'],
#      'plus.activation.overlayMessage': ['Subscribing to Plus…'],
#      'plus.basket.onboarding.cta': ['Get it free'],
#      'plus.basket.onboarding.cta.conservative': ['Free with Plus'],
#      'plus.landingPage.faqs.link': ['FAQs'],
#      'plus.landingPage.footnote': ['Partner eligibility applies. Subscription automatically renews after trial, and you can cancel any time. Only one account can be used for each subscription. This account will benefit from Deliveroo Plus. By clicking the button above, you agree to our Deliveroo Plus T&Cs.'],
#      'plus.landingPage.footnote.2019': ['Subscription automatically renews after trial, and you can cancel any time. By clicking the button above, you agree to our Deliveroo Plus T&Cs.'],
#      'plus.landingPage.heading': ['Join Deliveroo Plus'],
#      'plus.landingPage.introduction': ['Get unlimited delivery on the food you love'],
#      'plus.landingPage.legalTerms': ['T&Cs apply.'],
#      'plus.landingPage.login.button': ['Log in to check availability'],
#      'plus.landingPage.metaDescription': ["Deliveroo Plus is our subscription membership plan – you pay a flat monthly fee for unlimited free delivery. It's a simple, easy way to get the most out of Deliveroo. Members benefit from exclusive restaurant offers, which aren't available to other customers."],
#      'plus.landingPage.pageTitle': ['Deliveroo Plus'],
#      'plus.landingPage.paymentMethod(%(cardType)s, %(cardSource)s, %(paymentMethodLink)s)': ['Payment will be taken from [%(cardType)s ending %(cardDigits)s](%(paymentMethodLink)s)'],
#      'plus.landingPage.subscribe.button': ['Join now'],
#      'plus.landingPage.subscriber.body': ['We’re really excited you’re here — your unlimited delivery starts now.'],
#      'plus.landingPage.subscriber.buttonText': ['Find great restaurants nearby'],
#      'plus.landingPage.subscriber.heading(%(name)s)': ['Welcome to Deliveroo Plus, %(name)s'],
#      'plus.landingPage.trial.button': ['Start free trial now'],
#      'plus.landingPage.trial.button(%(trialDuration)s)': ['Try free for %(trialDuration)s days'],
#      'plus.landingPage.trial.button(%{trialDuration})': ['Try free for %{trialDuration} days'],
#      'plus.partner_offers.mastercard_au.code_error.button': ['Check eligibility'],
#      'plus.partner_offers.mastercard_au.code_error.subtitle': ['In order to redeem this offer, please check your card’s eligibility with Mastercard.'],
#      'plus.partner_offers.mastercard_au.code_error.title': ['Check eligibility'],
#      'plus.partner_offers.mastercard_au.errorBanner.employeeAccount.description': ["Sorry, this feature isn't available for Deliveroo employees."],
#      'plus.partner_offers.mastercard_au.errorBanner.employeeAccount.title': ['Employee account detected'],
#      'plus.partner_offers.mastercard_au.errorBanner.ineligibleCode.title': ['Offer not valid'],
#      'plus.partner_offers.mastercard_au.errorBanner.serviceUnavailable': ['Sorry, something went wrong – please try again.'],
#      'plus.partner_offers.mastercard_au.existing_payment_method': ['Use an existing payment method'],
#      'plus.partner_offers.mastercard_au.invalid_card': ['Please enter a valid Mastercard number'],
#      'plus.payment_method.card_type_and_digits(%(cardType)s %(cardDigits)s)': ['%(cardType)s ending %(cardDigits)s'],
#      'plus.prime.common.overlayMessage': ['Subscribing to Plus…'],
#      'plus.prime.errorBanner.accountAccessDenied.description': ["Sorry, we can't connect your accounts."],
#      'plus.prime.errorBanner.accountAccessDenied.title': ["We couldn't link your Prime membership to Deliveroo"],
#      'plus.prime.errorBanner.accountAlreadyLinked.description': ["You've already connected your Amazon account to another Deliveroo account."],
#      'plus.prime.errorBanner.accountAlreadyLinked.title': ["Sorry, we can't connect your accounts"],
#      'plus.prime.errorBanner.employeeAccount.description': ["Sorry, this feature isn't available for Deliveroo employees."],
#      'plus.prime.errorBanner.employeeAccount.title': ['Employee account detected'],
#      'plus.prime.errorBanner.existingOffer.description': ['It looks like you already have free Deliveroo Plus with Prime in another country.'],
#      'plus.prime.errorBanner.existingOffer.title': ["You've already used this offer"],
#      'plus.prime.errorBanner.generic.description': ['Please try again later.'],
#      'plus.prime.errorBanner.generic.title': ['Sorry, something went wrong'],
#      'plus.prime.errorBanner.partnerUnavailable.description': ['Join Amazon Prime to claim your free year of Deliveroo Plus.'],
#      'plus.prime.errorBanner.partnerUnavailable.title': ['You need a Prime membership to use this offer'],
#      'plus.prime.errorBanner.serverError.description': ['Sorry, something went wrong.'],
#      'plus.prime.errorBanner.serverError.title': ["We couldn't link your Prime membership to Deliveroo"],
#      'plus.prime.errorBanner.serviceUnavailable.description': ['Sorry, something went wrong – please try again.'],
#      'plus.prime.errorBanner.serviceUnavailable.title': ["We couldn't link your Prime membership to Deliveroo"],
#      'plus.prime.errorBanner.subscriptionCreation.description': ['Sorry, this offer has expired.'],
#      'plus.prime.errorBanner.subscriptionCreation.title': ['Your Deliveroo Plus offer is no longer available'],
#      'plus.prime.landingPage.loggedOut.appleCtaText': ['To sign in with Apple, use the Deliveroo app and go to your account.'],
#      'plus.prime.successBanner.login.title(%(email)s)': ['Logged in as %(email)s'],
#      'plus.prime.successBanner.subscriptionLinked.title': ['Successfully linked your Amazon account'],
#      'plus.signup.cta.pay_and_subscribe(%(amount)s)': ['Pay %(amount)s and subscribe'],
#      'plus.signup.error.add_payment_method_failure': ["Couldn't add payment card."],
#      'plus.signup.error.create_subscription_failure': ["Couldn't subscribe."],
#      'plus.signup.error.payment_methods_failure': ['Failed to retrieve the list of payment methods.'],
#      'plus.signup.start_free_trial_now': ['Start your free trial now'],
#      'plus.signup.subscribe_and_pay': ['Subscribe and Pay'],
#      'plus.subscription.payment_method.title': ['Payment method'],
#      'plus_on_time_promise_body': ['You’ve received your credit'],
#      'plus_on_time_promise_title': ['On-time Promise'],
#      'Popular': ['Popular'],
#      'Postcode': ['Postcode'],
#      'post_order_tip.custom_tip_options.message': ['Or, leave a custom tip'],
#      'post_order_tip.tip_options.title': ['Choose an amount'],
#      'poweredByDeliveroo': ['Powered by Deliveroo'],
#      'pre-order': ['pre-order'],
#      'Privacy': ['Privacy'],
#      'privacy_policy.see_more': ['See more'],
#      'Processing your order...': ['Processing your order...'],
#      'Project code is required': ['Project code is required'],
#      'Promo code': ['Promo code'],
#      'Promotion code %(code)s is not valid': ['Promotion code %(code)s is not valid'],
#      'qr_code_page.button.already_scanned_cta': ["I've scanned the QR code"],
#      'qr_code_page.error.fetch_order_status': ["That didn't work. Wait a few seconds and try again."],
#      'qr_code_page.error.order_ui_status': ["That didn't work. Make sure you've scanned the code and try again."],
#      'qr_code_page.fetch_qr_code_url_error.try_again': ['Try again'],
#      'qr_code_page.fetch_qr_code_url_error.wechat_pay': ['We couldn’t get the WeChat Pay QR code.\nTry again or refresh your browser.'],
#      'qr_code_page.instruction.wechat_pay': ['Scan the QR code with WeChat Pay to complete your payment to Deliveroo'],
#      'qr_code_page.page_title': ['Deliveroo | Scan QR'],
#      'qr_code_page.payment_method.wechat_pay': ['WeChat Pay'],
#      'qr_code_page.payment_method.wechat_pay.alt_text': ['WeChat Pay logo'],
#      'qr_code_page.total': ['Total'],
#      "Questions about your order? %{brtag} We're here to help! Email us at %{email}  or call us on %{phone_number}": ["Questions about your order? %{brtag} We're here to help! Email us at %{email} or call us on %{phone_number}"],
#      'rating.descriptiveText.excellent': ['Excellent'],
#      'rating.descriptiveText.good': ['Good'],
#      'rating.descriptiveText.veryGood': ['Very good'],
#      'Ratings': ['Ratings'],
#      'Recent addresses': ['Recent addresses'],
#      'recommendations.continue_to_checkout.button': ['Continue to checkout'],
#      'recommendations.review_basket.button': ['Review basket'],
#      'Refund': ['Refund'],
#      'Registered Office:': ['Registered Office:'],
#      'Registration': ['Registration'],
#      'Remaining': ['Remaining'],
#      'Reorder': ['Reorder'],
#      'report_restaurant_reply.thank_you.heading': ['Thanks for reporting'],
#      'report_restaurant_reply.thank_you.subheading': ['Our team will investigate and, if necessary, speak to this partner to make sure it doesn’t happen again.'],
#      'report_restaurant_reply_dialog.button.title': ['Report this reply'],
#      'report_restaurant_reply_dialog.explain_in_detail.message_placeholder': ['E.g. I was offended by the language'],
#      'report_restaurant_reply_dialog.explain_in_detail.title': ['Explain in more detail (optional)'],
#      'report_restaurant_reply_dialog.report_reason.reason_1': ['I find it rude or unprofessional'],
#      'report_restaurant_reply_dialog.report_reason.reason_2': ['It uses threatening language'],
#      'report_restaurant_reply_dialog.report_reason.reason_3': ['It includes my private information'],
#      'report_restaurant_reply_dialog.report_reason.reason_4': ['It’s hateful against a protected characteristic (e.g. race, religion, gender, orientation, disability)'],
#      'report_restaurant_reply_dialog.report_reason.title': ['Why are you reporting this reply? '],
#      'report_restaurant_reply_dialog.title': ['Report a restaurant reply'],
#      'Reset password': ['Reset password'],
#      'restaurant.allergen_warning.message(%{restaurant})': ["%{restaurant} can't guarantee your food won't contain traces of allergens such as nuts or dairy, as delivery orders are cooked in kitchens where allergens may be present."],
#      'restaurant.allergen_warning.title': ['Allergen notice'],
#      'restaurant_fulfilled.menu.delivery_time(%(targetDeliveryTime)s)': ['Around %(targetDeliveryTime)s min'],
#      'restaurant_list.choose_delivery_day': ['Schedule your delivery to arrive as soon as possible, later today or tomorrow'],
#      'restaurant_list.choose_delivery_time': ['Select a time of day for your delivery'],
#      'restaurant_list.deliveroo_fulfilled.delivery_time_label': ['min'],
#      ...}}},
#   'sentryContext': {'req': {'url': "/menu/London/king's-cross/10709-kfc-kings-cross-uk?day=today&postcode=EC&time=ASAP",
#     'method': 'GET',
#     'headers': {'x-forwarded-for': '192.54.222.141, 162.158.63.159, 10.0.65.196',
#      'x-forwarded-proto': 'https',
#      'x-forwarded-port': '443',
#      'host': 'deliveroo.co.uk',
#      'x-amzn-trace-id': 'Self=1-6480d2f6-7ea3370677ba82656edeecb4;Root=1-6480d2f6-138d42cc1f6d5ff37299da43',
#      'accept-encoding': 'gzip, deflate, br',
#      'cf-ray': '7d3b1e242ae9c336-EWR',
#      'cf-visitor': '{"scheme":"https"}',
#      'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.63 Safari/537.36',
#      'accept': '*/*',
#      'cdn-loop': 'cloudflare',
#      'cf-connecting-ip': '192.54.222.141',
#      'true-client-ip': '192.54.222.141',
#      'cf-ipcountry': 'US',
#      'roo-bot-score': '1',
#      'roo-cf-asn': '396527',
#      'roo-cf-ja3': '8d9f7747675e24454cd9b7ed35c58707',
#      'roo-verified-bot': 'false',
#      'x-roo-server-name': 'cwa_gb'},
#     'params': {'city': 'London',
#      'neighborhood': "king's-cross",
#      'restaurant': '10709-kfc-kings-cross-uk'},
#     'query': {'day': 'today', 'postcode': 'EC', 'time': 'ASAP'},
#     'cookies': {},
#     'locale': 'en',
#     'country': {'tld': 'uk',
#      'host': 'deliveroo.co.uk',
#      'isoCode': 'GB',
#      'languages': ['en'],
#      'examplePostcode': 'EC4R 3TE',
#      'postcodeSearch': True,
#      'riderInviteLink': True,
#      'restaurantsHomepageUrl': {'default': 'https://restaurants.deliveroo.com/'},
#      'appRatings': {'itunesCount': '482,088',
#       'itunesRating': 4.6,
#       'googleCount': '131,970',
#       'googleRating': 4.3},
#      'enableDeliverooForBusiness': True,
#      'salesforceKey': 'UK',
#      'isHidden': False,
#      'callingCode': 44},
#     'sentryTransaction': '/menu/[city]/[neighborhood]/[restaurant]',
#     'whiteLabel': {}},
#    'res': {'locals': {'roo_guid': '823e88cc-74fe-4626-af25-728ede415373',
#      'roo_session_guid': '4067707c-0113-4188-94ae-5fbdcb792468',
#      'debugErrorId': '23746e57-48d4-43d1-8185-375f54a36087'}},
#    'pathname': '/menu/[city]/[neighborhood]/[restaurant]',
#    'unverifiedUserId': None},
#   'showLoginSuccessBanner': False},
#  'page': '/menu/[city]/[neighborhood]/[restaurant]',
#  'query': {'day': 'today',
#   'postcode': 'EC',
#   'time': 'ASAP',
#   'city': '[city]',
#   'neighborhood': '[neighborhood]',
#   'restaurant': '[restaurant]'},
#  'buildId': 'hZcTT4K1KER7Ly4eNn9Rp',
#  'assetPrefix': 'https://cwa.roocdn.com',
#  'runtimeConfig': {'cdnHost': 'https://cwa.roocdn.com',
#   'chatWebClientURL': 'https://chat-web-client.roocdn.com/index.html',
#   'clientEventsEndpoint': 'https://events-tracker.deliveroo.net/track',
#   'environmentName': 'production',
#   'geoshardedApiHost': 'https://api.{MARKET}.deliveroo.com',
#   'googleTagManagerID': 'GTM-PMJMHHC',
#   'businessPageGoogleTagManagerID': 'GTM-M42ZSPH',
#   'hopperImageTag': '3c04f81a7dbf5acfb8bd5364003790bcee4c4e01',
#   'hopperInstanceId': 'production/0d26f66f077e4207bc2bc978ad2bfc78',
#   'hopperReleaseId': '126044',
#   'hopperTaskId': '66a9c412-ca6e-452f-aa2f-8a77e2effeea',
#   'orderHelpWebClientUrl': 'https://order-help-web-client.roocdn.com/index.html',
#   'prismicHost': 'deliveroo.cdn.prismic.io',
#   'sentryDsn': 'https://438fd54084e74e9a85dc25f8e0772763@o74967.ingest.sentry.io/1328685',
#   'storyblokApiKey': 'YjuPjz0EwVMAS7AQie5RCAtt',
#   'storyblokApiNewsKey': 'T5yp0AkcLSKFHaQ0nuPblwtt',
#   'storyblokCuisinesEnabled': True,
#   'storyblokHost': 'https://api.storyblok.com',
#   'supportDrnIdsEnabled': False,
#   'isRunningE2E': False,
#   'googleMapsApiKey': 'AIzaSyDPv3G1YKuMDe107nqQB5LrsfSfCQYU7MI',
#   'accountMobileVerificationAppUrl': 'https://mobile-verification.roocdn.com/index.html',
#   'googleOauth2ClientId': '503757482204-dmiski9tsv4kih4q39bt32lgvdn6e8su.apps.googleusercontent.com',
#   'facebookAppId': '715101428613026',
#   'appleClientId': 'com.deliveroo.auth.web.apple.v1.0',
#   'debugModalURL': 'https://deliveroo.atlassian.net/servicedesk/customer/portal/5/group/20/create'},
#  'isFallback': False,
#  'dynamicIds': [70848, 50580],
#  'customServer': True,
#  'appGip': True,
#  'locale': 'en-gb',
#  'locales': ['en-gb',
#   'ar',
#   'ar-kw',
#   'ar-qa',
#   'de',
#   'en',
#   'es',
#   'fr',
#   'it',
#   'nl',
#   'nl-be',
#   'zh',
#   'zh-tw',
#   'en-au',
#   'en-ie',
#   'en-sg',
#   'en-ae'],
#  'defaultLocale': 'en-gb',
#  'domainLocales': [{'domain': 'deliveroo.co.uk', 'defaultLocale': 'en-gb'},
#   {'domain': 'deliveroo.com.au', 'defaultLocale': 'en-au'},
#   {'domain': 'deliveroo.ie', 'defaultLocale': 'en-ie'},
#   {'domain': 'deliveroo.com.sg', 'defaultLocale': 'en-sg'},
#   {'domain': 'deliveroo.ae', 'defaultLocale': 'en-ae'}],
#  'scriptLoader': []}

# %%
def fetch_restaurant_details(details_json=details_json):
    #TODO: Check the name here
    restaurant = details_json['props']['initialState']['menuPage']['menu']['meta']['restaurant']
    name = restaurant['name']
    # in place of restaurant slug we'll use a lower case name, replacing he spaces w _
    formatted_name = name.lower().replace(" ", "_")
    address = restaurant['location']['address']['address1']
    #neighborhood = restaurant['location']['address']['neighborhood']

    print("Name:", formatted_name)
    print("Address:", address)
    #print("Neighborhood:", neighborhood)    

            #restaurant_details['restaurant_address'] = [restaurant_json['location']['address']['address1']]
            #print(restaurant_details)
    #restaurant_json2 = self.__details_json['props']['initialState']['menuPage']['menu']['meta']['customerLocation']
    #print(restaurant_json2)
    # self.__restaurant_details['latitude'] = [float(restaurant_json2['lat'])]
    # self.__restaurant_details['longitude'] = [float(restaurant_json2['lon'])]
    # self.__restaurant_details['neighborhood'] = [restaurant_json2['neighborhood']]
    # self.__restaurant_details['postcode'] = [restaurant_json2['postcode']]
    # self.__restaurant_details['geohash'] = [restaurant_json2['geohash']]

    # Modified name will replace 'restaurantSluG'


    # Get restaurant name and put it in lower case for the filename
    # restaurant_name = self.__restaurant_details['restaurant_name']
    # restaurant_name = restaurant_name[0]
    # self.__modified_name = restaurant_name.lower().replace(" ", "")
    #print(modified_name)

    #self.__restaurant_details['menu_file'] = [self.__restaurant_details['restaurant_name'].lower().replace(" ", "_") + '.csv']

#     except KeyError as e:
#         flag = False
#         restaurant_details = {}
#         logging.error(f'Invalid key {e}')

#     except Exception as e:
#         restaurant_details = {}
#         flag = False
#         logging.error(e)

#     # call other function(s)
#     if flag:
#         fetch_restaurant_menu_details()

# %%
fetch_restaurant_details(details_json)
# Out:
# Name: kfc_-_kings_cross
# Address: 323 Grays Inn Road, London, WC1X8PX

# %%
def fetch_restaurant_location(details_json):
    rest = details_json['props']['initialState']['menuPage']['menu']['meta']['customerLocation']

    lat = rest['lat']
    lon = rest['lon']
    city = rest['city']
    neighborhood = rest['neighborhood']
    postcode = rest['postcode']
    cityId = rest['cityId']
    zoneId = rest['zoneId']
    geohash = rest['geohash']

    # You can now use these variables as needed, for example, print them:
    print("Latitude:", lat)
    print("Longitude:", lon)
    print("City:", city)
    print("Neighborhood:", neighborhood)
    print("Postcode:", postcode)
    print("City ID:", cityId)
    print("Zone ID:", zoneId)
    print("Geohash:", geohash)

# %%
fetch_restaurant_location(details_json)
# Out:
# Latitude: 51.5287716
# Longitude: -0.1320632
# City: London
# Neighborhood: Somers Town
# Postcode: EC
# City ID: 1
# Zone ID: 7481
# Geohash: gcpvhuxbfenx

# %%
def __fetch_restaurant_menu_details(self):
    # Perhaps add this?     # Attempt to parse the JSON string -> parsed_json = json.loads(json_string)
    try:
        # Convert the dictionary to a JSON string
        #json_string = json.dumps(self.__details_json)
        #self.__details_json = json.loads(json_string)
        
        #print("The menu dictionary is JSON-like.")
    menu = details_json['props']['initialState']['menuPage']['menu']['meta']['items']
    for item in restaurant_json:
            name = item['name']
            description = item['description']
            price = item['price']['formatted']
    
            nutritional_info = None
            if 'nutritionalInfo' in item and item['nutritionalInfo'] is not None:
                nutritional_info = item['nutritionalInfo']['energyFormatted']
    
            url = None
            if 'image' in item and item['image'] is not None:
                url = item['image']['url']
            #restaurant_details['restaurant_name']
            #name= restaurant_json['name']
            
            print("Name:", name)
            print("Description:", description)
            print("Price:", price)
            print("URL:", url)
            print("Nutritional Info:", nutritional_info)
            print("\n")        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        menu_json = self.__details_json['props']['initialState']['menuPage']['menu']['meta']['items']

        if len(menu_json) < 1:
            self.__flag = False
            return

        for menu in menu_json:
            temp = {
                'item_name': menu['name'],
                'item_description': menu['description'],
                'item_nutritional_info' : menu['nutritionalInfo']['energyFormatted'],
                'item_price': menu['price']['formatted'],
                'item_image': menu['image']['url'],
            }
            self.__restaurant_menu_details.append(temp)

    except KeyError as e:
        self.__flag = False
        self.__restaurant_menu_details = []
        logging.error(f'Invalid key {e}')

    except Exception as e:
        self.__flag = False
        self.__restaurant_menu_details = []
        logging.error(e)

# %%
def get_restaurant_details(self) -> None | DataFrame:
    if not self.__flag:
        return None
    return DataFrame(self.__restaurant_details)

def get_restaurant_menu(self) -> None | DataFrame:
    if not self.__flag:
        return None
    return DataFrame(self.__restaurant_menu_details)

def write_to_csv(self):
    if self.__flag and self.__restaurant_details != {} and self.__restaurant_menu_details != []:
        self.__write_restaurant_details()
        self.__write_restaurant_menu()

    else:
        logging.error(f'Cannot write into file')

def __write_restaurant_details(self):
    makedirs(self.__base_dir, exist_ok=True)
    filename = self.__base_dir / (self.__filename + '.csv')

    try:
        df_1 = read_csv(filename)
        df_2 = DataFrame(self.__restaurant_details)
        df = concat([df_1, df_2])
        df.drop_duplicates(inplace=True)
        df.to_csv(filename, index=False)

    except FileNotFoundError:
        df = DataFrame(self.__restaurant_details)
        df.to_csv(filename, index=False)

    except Exception as e:
        logging.error(f'{e}\nCannot write restaurant details')

def __write_restaurant_menu(self):
    makedirs(self.__menu_dir, exist_ok=True)
    filename = self.__menu_dir / self.__restaurant_details['menu_file'][0]

    try:
        df = DataFrame(self.__restaurant_menu_details)
        df.to_csv(filename, index=False)
    except Exception as e:
        logging.error(f'{e}\nCannot write restaurant menu details')

# %% [markdown]
# ## ISSUE W FETCH DETAILS
